# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read file
renew = pd.read_csv('clean_data/renewable_energy.csv')
renew
# Out:
#                                country    1965.0    1966.0    1967.0  \
# 0                               Canada  0.000000  0.000000  0.000000
# 1                               Mexico  0.000000  0.000000  0.000000
# 2                                   US  0.133322  0.140620  0.140736
# 3                  Total North America  0.133322  0.140620  0.140736
# 4                            Argentina  0.000000  0.000000  0.000000
# ..                                 ...       ...       ...       ...
# 98                  Total Asia Pacific  0.016440  0.016430  0.014240
# 99                         Total World  0.214179  0.233071  0.235538
# 100                     of which: OECD  0.179852  0.198060  0.199866
# 101                           Non-OECD  0.034327  0.035011  0.035672
# 102                   European Union #  0.029090  0.039790  0.043160
#
#        1968.0    1969.0    1970.0    1971.0    1972.0    1973.0  ...  \
# 0    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.001610  ...
# 2    0.155460  0.162271  0.162359  0.165844  0.186730  0.199897  ...
# 3    0.155460  0.162271  0.162359  0.165844  0.186730  0.201507  ...
# 4    0.000000  0.000000  0.000475  0.000499  0.000644  0.000490  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 98   0.015770  0.016080  0.017767  0.017546  0.017856  0.018350  ...
# 99   0.257519  0.269545  0.298667  0.322760  0.347499  0.368311  ...
# 100  0.221200  0.232580  0.251310  0.256369  0.276382  0.297001  ...
# 101  0.036319  0.036966  0.047357  0.066391  0.071118  0.071310  ...
# 102  0.048180  0.052430  0.069403  0.070579  0.069259  0.074422  ...
#
#        2010.0     2011.0     2012.0     2013.0     2014.0     2015.0  \
# 0    0.216234   0.250820   0.278884   0.290927   0.303300   0.437742
# 1    0.086040   0.088399   0.102050   0.111551   0.133273   0.157067
# 2    2.756646   3.090966   3.325100   3.756286   4.039290   4.248825
# 3    3.058920   3.430186   3.706035   4.158765   4.475862   4.843633
# 4    0.040601   0.052376   0.065415   0.070381   0.077710   0.082616
# ..        ...        ...        ...        ...        ...        ...
# 98   1.953708   2.379845   2.840311   3.491201   4.214132   4.845924
# 99   9.699337  11.120646  12.604510  14.360242  16.027352  18.081068
# 100  7.119965   8.157404   9.131990  10.116568  10.936214  12.182050
# 101  2.579372   2.963241   3.472520   4.243674   5.091138   5.899018
# 102  3.376245   3.980388   4.615612   5.023238   5.383986   6.023025
#
#         2016.0     2017.0     2018.0     2019.0
# 0     0.488314   0.492008   0.503491   0.523399
# 1     0.170452   0.184147   0.216463   0.345292
# 2     4.807667   5.239283   5.503936   5.828555
# 3     5.466434   5.915439   6.223889   6.697246
# 4     0.081679   0.094728   0.100514   0.138995
# ..         ...        ...        ...        ...
# 98    5.957339   7.532352   9.285780  10.814118
# 99   20.057078  23.036529  25.825912  28.976463
# 100  12.960876  14.323605  15.272031  16.770755
# 101   7.096202   8.712925  10.553881  12.205708
# 102   6.050515   6.692393   6.969224   7.541291
#
# [103 rows x 56 columns]

# %%
renew.at[102, "country"] = "EU"

# %%
renew.at[99, "country"] = "Global"

# %%
renewable_df = renew[renew["country"].isin(["Global", "US", "EU", "India", "China"])]
renewable_df
# Out:
#     country    1965.0    1966.0    1967.0    1968.0    1969.0    1970.0  \
# 2        US  0.133322  0.140620  0.140736  0.155460  0.162271  0.162359
# 82    China  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 84    India  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 99   Global  0.214179  0.233071  0.235538  0.257519  0.269545  0.298667
# 102      EU  0.029090  0.039790  0.043160  0.048180  0.052430  0.069403
#
#        1971.0    1972.0    1973.0  ...    2010.0     2011.0     2012.0  \
# 2    0.165844  0.186730  0.199897  ...  2.756646   3.090966   3.325100
# 82   0.000000  0.000000  0.000000  ...  0.768617   1.049599   1.356394
# 84   0.000000  0.000000  0.000000  ...  0.318274   0.393996   0.460994
# 99   0.322760  0.347499  0.368311  ...  9.699337  11.120646  12.604510
# 102  0.070579  0.069259  0.074422  ...  3.376245   3.980388   4.615612
#
#         2013.0     2014.0     2015.0     2016.0     2017.0     2018.0  \
# 2     3.756286   4.039290   4.248825   4.807667   5.239283   5.503936
# 82    1.795909   2.238405   2.623552   3.439668   4.614891   5.805106
# 84    0.518092   0.579871   0.597314   0.729589   0.896848   1.103764
# 99   14.360242  16.027352  18.081068  20.057078  23.036529  25.825912
# 102   5.023238   5.383986   6.023025   6.050515   6.692393   6.969224
#
#         2019.0
# 2     5.828555
# 82    6.627562
# 84    1.207505
# 99   28.976463
# 102   7.541291
#
# [5 rows x 56 columns]

# %%
# Flip the df
renewT = renewable_df.T
renewT = renewT.reset_index(drop=False)
# Rename columns
renewT = renewT.rename(columns={"index":"year", 99: "oil"})
# all_energyT.set_index("year", inplace=True)
renewT

renew_final = renewT.rename(columns={2:'US', 82:'China', 84:'India', 'oil' :'Global', 102:'EU'})

renew_final = renew_final.iloc[1:]
renew_final.head()
# Out:
#      year        US China India    Global       EU
# 1  1965.0  0.133322     0     0  0.214179  0.02909
# 2  1966.0   0.14062     0     0  0.233071  0.03979
# 3  1967.0  0.140736     0     0  0.235538  0.04316
# 4  1968.0   0.15546     0     0  0.257519  0.04818
# 5  1969.0  0.162271     0     0  0.269545  0.05243

# %%
# To see the trend lines

# %%
plt.scatter(renew_final.year, renew_final.US)

# %%
plt.scatter(renew_final.year, renew_final.China)

# %%
plt.scatter(renew_final.year, renew_final.India)

# %%
plt.scatter(renew_final.year, renew_final.Global)

# %%
plt.scatter(renew_final.year, renew_final.EU)

# %%
# Check types
renew_final.dtypes
# Out:
# year      object
# US        object
# China     object
# India     object
# Global    object
# EU        object
# dtype: object

# %%
# Convert types
renew_final = renew_final[["year", "Global", "US", "EU", "India", "China"]].astype(float)
renew_final
# Out:
#       year     Global        US        EU     India     China
# 1   1965.0   0.214179  0.133322  0.029090  0.000000  0.000000
# 2   1966.0   0.233071  0.140620  0.039790  0.000000  0.000000
# 3   1967.0   0.235538  0.140736  0.043160  0.000000  0.000000
# 4   1968.0   0.257519  0.155460  0.048180  0.000000  0.000000
# 5   1969.0   0.269545  0.162271  0.052430  0.000000  0.000000
# 6   1970.0   0.298667  0.162359  0.069403  0.000000  0.000000
# 7   1971.0   0.322760  0.165844  0.070579  0.000000  0.000000
# 8   1972.0   0.347499  0.186730  0.069259  0.000000  0.000000
# 9   1973.0   0.368311  0.199897  0.074422  0.000000  0.000000
# 10  1974.0   0.385606  0.204043  0.078293  0.000000  0.000000
# 11  1975.0   0.388276  0.197543  0.082826  0.000000  0.000000
# 12  1976.0   0.429518  0.225648  0.083056  0.000000  0.000000
# 13  1977.0   0.465105  0.235361  0.086462  0.000000  0.000000
# 14  1978.0   0.507545  0.246788  0.091219  0.000000  0.000000
# 15  1979.0   0.557800  0.257560  0.092913  0.000000  0.000000
# 16  1980.0   0.604134  0.266561  0.103978  0.000000  0.000000
# 17  1981.0   0.632315  0.273776  0.100949  0.000000  0.000000
# 18  1982.0   0.743240  0.264050  0.093057  0.000000  0.000000
# 19  1983.0   0.843447  0.298103  0.095990  0.000000  0.000000
# 20  1984.0   0.956693  0.356072  0.099855  0.000000  0.000000
# 21  1985.0   1.010417  0.364095  0.104726  0.000000  0.000000
# 22  1986.0   1.147124  0.387201  0.124135  0.000000  0.000000
# 23  1987.0   1.213562  0.426796  0.122421  0.000000  0.000000
# 24  1988.0   1.257334  0.424041  0.131548  0.000000  0.000000
# 25  1989.0   1.404412  0.512408  0.131837  0.000000  0.000000
# 26  1990.0   1.579746  0.670078  0.187564  0.000679  0.000680
# 27  1991.0   1.656818  0.713814  0.195407  0.002080  0.000751
# 28  1992.0   1.745224  0.765212  0.212959  0.002079  0.002473
# 29  1993.0   1.815543  0.802285  0.242770  0.003468  0.003331
# 30  1994.0   1.913737  0.813046  0.263797  0.005716  0.008488
# 31  1995.0   2.007832  0.787385  0.298167  0.010613  0.036372
# 32  1996.0   2.040488  0.770712  0.313089  0.016406  0.016359
# 33  1997.0   2.195189  0.803576  0.391132  0.019757  0.029310
# 34  1998.0   2.314628  0.810033  0.470468  0.023776  0.028496
# 35  1999.0   2.460757  0.838034  0.518442  0.031381  0.030107
# 36  2000.0   2.639702  0.868178  0.650380  0.033788  0.031489
# 37  2001.0   2.754379  0.886655  0.719425  0.042583  0.033018
# 38  2002.0   3.097275  0.996221  0.877077  0.042954  0.035471
# 39  2003.0   3.370340  1.058536  1.034605  0.053512  0.041101
# 40  2004.0   3.869028  1.152707  1.296742  0.084781  0.057830
# 41  2005.0   4.371778  1.241083  1.557544  0.098864  0.101235
# 42  2006.0   5.026240  1.468457  1.835124  0.145510  0.143089
# 43  2007.0   5.944938  1.679495  2.210652  0.184962  0.196720
# 44  2008.0   7.158576  2.107577  2.575745  0.228126  0.326148
# 45  2009.0   8.240148  2.394484  2.917109  0.265121  0.524563
# 46  2010.0   9.699337  2.756646  3.376245  0.318274  0.768617
# 47  2011.0  11.120646  3.090966  3.980388  0.393996  1.049599
# 48  2012.0  12.604510  3.325100  4.615612  0.460994  1.356394
# 49  2013.0  14.360242  3.756286  5.023238  0.518092  1.795909
# 50  2014.0  16.027352  4.039290  5.383986  0.579871  2.238405
# 51  2015.0  18.081068  4.248825  6.023025  0.597314  2.623552
# 52  2016.0  20.057078  4.807667  6.050515  0.729589  3.439668
# 53  2017.0  23.036529  5.239283  6.692393  0.896848  4.614891
# 54  2018.0  25.825912  5.503936  6.969224  1.103764  5.805106
# 55  2019.0  28.976463  5.828555  7.541291  1.207505  6.627562

# %%
countries_no_zero = renew_final[["year", "Global", "US", "EU"]]
countries_no_zero.head()
# Out:
#      year    Global        US       EU
# 1  1965.0  0.214179  0.133322  0.02909
# 2  1966.0  0.233071  0.140620  0.03979
# 3  1967.0  0.235538  0.140736  0.04316
# 4  1968.0  0.257519  0.155460  0.04818
# 5  1969.0  0.269545  0.162271  0.05243

# %%
# Create columns with nonzero-value
no_zero = renew_final[renew_final["India"] > 0]
no_zero
# Out:
#       year     Global        US        EU     India     China
# 26  1990.0   1.579746  0.670078  0.187564  0.000679  0.000680
# 27  1991.0   1.656818  0.713814  0.195407  0.002080  0.000751
# 28  1992.0   1.745224  0.765212  0.212959  0.002079  0.002473
# 29  1993.0   1.815543  0.802285  0.242770  0.003468  0.003331
# 30  1994.0   1.913737  0.813046  0.263797  0.005716  0.008488
# 31  1995.0   2.007832  0.787385  0.298167  0.010613  0.036372
# 32  1996.0   2.040488  0.770712  0.313089  0.016406  0.016359
# 33  1997.0   2.195189  0.803576  0.391132  0.019757  0.029310
# 34  1998.0   2.314628  0.810033  0.470468  0.023776  0.028496
# 35  1999.0   2.460757  0.838034  0.518442  0.031381  0.030107
# 36  2000.0   2.639702  0.868178  0.650380  0.033788  0.031489
# 37  2001.0   2.754379  0.886655  0.719425  0.042583  0.033018
# 38  2002.0   3.097275  0.996221  0.877077  0.042954  0.035471
# 39  2003.0   3.370340  1.058536  1.034605  0.053512  0.041101
# 40  2004.0   3.869028  1.152707  1.296742  0.084781  0.057830
# 41  2005.0   4.371778  1.241083  1.557544  0.098864  0.101235
# 42  2006.0   5.026240  1.468457  1.835124  0.145510  0.143089
# 43  2007.0   5.944938  1.679495  2.210652  0.184962  0.196720
# 44  2008.0   7.158576  2.107577  2.575745  0.228126  0.326148
# 45  2009.0   8.240148  2.394484  2.917109  0.265121  0.524563
# 46  2010.0   9.699337  2.756646  3.376245  0.318274  0.768617
# 47  2011.0  11.120646  3.090966  3.980388  0.393996  1.049599
# 48  2012.0  12.604510  3.325100  4.615612  0.460994  1.356394
# 49  2013.0  14.360242  3.756286  5.023238  0.518092  1.795909
# 50  2014.0  16.027352  4.039290  5.383986  0.579871  2.238405
# 51  2015.0  18.081068  4.248825  6.023025  0.597314  2.623552
# 52  2016.0  20.057078  4.807667  6.050515  0.729589  3.439668
# 53  2017.0  23.036529  5.239283  6.692393  0.896848  4.614891
# 54  2018.0  25.825912  5.503936  6.969224  1.103764  5.805106
# 55  2019.0  28.976463  5.828555  7.541291  1.207505  6.627562

# %%
plt.scatter(no_zero.year, no_zero.China)

# %%
plt.scatter(no_zero.year, no_zero.Global)

# %%
plt.scatter(no_zero.year, no_zero.US)

# %% [markdown]
# #### Will seperate countries in two batch, India & China, the rest together

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = countries_no_zero.year.values.reshape(-1, 1)
y = np.log(countries_no_zero[["US", "EU"]])

print(X.shape, y.shape)
# Out:
# (55, 1) (55, 2)

# %%
# Split the data into training and testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# Create a LinearRegression model and fit it to the scaled training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
# Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
# plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2
models = []

from sklearn.metrics import mean_squared_error

lr_predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, lr_predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "LinearRegression",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.0402328284019258, R2: 0.9529305003773582

# %%
#  LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01)
lasso.fit(X_train_scaled, y_train_scaled)

las_predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, las_predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "Lasso",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.039977878701726206, R2: 0.9532307205768757

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01)
elasticnet.fit(X_train_scaled, y_train_scaled)

ela_predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, ela_predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "ElasticNet",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.03998096571961317, R2: 0.9532270653860182

# %%
a = pd.DataFrame(models)
a
# Out:
#               model       MSE        R2
# 0  LinearRegression  0.040233  0.952931
# 1             Lasso  0.039978  0.953231
# 2        ElasticNet  0.039981  0.953227

# %%
a[a["R2"]==a["R2"].max()]
# Out:
#    model       MSE        R2
# 1  Lasso  0.039978  0.953231

# %%
a[a["MSE"]==a["MSE"].min()]
# Out:
#    model       MSE        R2
# 1  Lasso  0.039978  0.953231

# %% [markdown]
# ### Using Lasso

# %%
new_years = [2020, 2030, 2040, 2050]

# %%
year_df = pd.DataFrame(new_years, columns = ['year'])
year_df
# Out:
#    year
# 0  2020
# 1  2030
# 2  2040
# 3  2050

# %%
# Assign X (data) and y (target)
new_X = year_df["year"].values.reshape(-1, 1)

# %%
# Create a StandardScaler model for the new_X

new_X_scaled = X_scaler.transform(new_X)

# %%
# Prediction
energy_predictions = np.exp(lasso.predict(new_X_scaled))

# %%
y_new_inverse = y_scaler.inverse_transform(energy_predictions)
y_new_inverse
# Out:
# array([[ 5.98222835,  8.3790382 ],
#        [11.3123493 , 16.10367211],
#        [21.0831549 , 30.16374243],
#        [38.99431358, 55.75532122]])

# %%
non_zero_countries_prediction = pd.DataFrame(y_new_inverse, columns=["US", "EU"])
non_zero_countries_prediction
# Out:
#           US         EU
# 0   5.982228   8.379038
# 1  11.312349  16.103672
# 2  21.083155  30.163742
# 3  38.994314  55.755321

# %%
china_nonrenewable = pd.concat([year_df, non_zero_countries_prediction], axis=1)
china_nonrenewable
# Out:
#    year         US         EU
# 0  2020   5.982228   8.379038
# 1  2030  11.312349  16.103672
# 2  2040  21.083155  30.163742
# 3  2050  38.994314  55.755321

# %% [markdown]
# ## Add to the previous df

# %%
# Read file
global_renew = pd.read_csv('clean_data/renew_global_predictions.csv')
global_renew
# Out:
#    Unnamed: 0  years  predictions
# 0           0   2020    21.232078
# 1           1   2030    51.101937
# 2           2   2040   122.993520
# 3           3   2050   296.024120

# %%
china_only = renew_final[["year", "China"]]
china_only
# Out:
#       year    China
# 1   1965.0  5.51604
# 2   1966.0    5.995
# 3   1967.0  5.39134
# 4   1968.0  5.44535
# 5   1969.0  6.62766
# 6   1970.0  8.48661
# 7   1971.0  10.0617
# 8   1972.0  10.8466
# 9   1973.0  11.4491
# 10  1974.0  11.8055
# 11  1975.0  13.2215
# 12  1976.0  13.9209
# 13  1977.0  15.1808
# 14  1978.0  16.6474
# 15  1979.0  17.1472
# 16  1980.0  17.4826
# 17  1981.0  17.2475
# 18  1982.0  18.0097
# 19  1983.0  19.1665
# 20  1984.0   20.565
# 21  1985.0  22.2425
# 22  1986.0  23.3111
# 23  1987.0  25.1393
# 24  1988.0  27.0029
# 25  1989.0  28.3344
# 26  1990.0  28.7004
# 27  1991.0  30.1521
# 28  1992.0  31.7503
# 29  1993.0  34.1865
# 30  1994.0  36.2838
# 31  1995.0  37.3711
# 32  1996.0  39.3393
# 33  1997.0  39.5554
# 34  1998.0  39.6104
# 35  1999.0  40.9983
# 36  2000.0  42.4217
# 37  2001.0   44.809
# 38  2002.0  48.8091
# 39  2003.0  56.8341
# 40  2004.0  66.4879
# 41  2005.0  75.5005
# 42  2006.0  82.7374
# 43  2007.0  89.8911
# 44  2008.0  93.1188
# 45  2009.0  96.9986
# 46  2010.0  103.515
# 47  2011.0  111.491
# 48  2012.0  115.689
# 49  2013.0  119.579
# 50  2014.0   121.96
# 51  2015.0  122.753
# 52  2016.0  123.511
# 53  2017.0  126.217
# 54  2018.0  129.966
# 55  2019.0  135.072

# %%
china_only_all = china_only.append(china_nonrenewable)
china_only_all.set_index("year", inplace=True)
china_only_all
# Out:
#           China
# year
# 1965.0  5.51604
# 1966.0    5.995
# 1967.0  5.39134
# 1968.0  5.44535
# 1969.0  6.62766
# 1970.0  8.48661
# 1971.0  10.0617
# 1972.0  10.8466
# 1973.0  11.4491
# 1974.0  11.8055
# 1975.0  13.2215
# 1976.0  13.9209
# 1977.0  15.1808
# 1978.0  16.6474
# 1979.0  17.1472
# 1980.0  17.4826
# 1981.0  17.2475
# 1982.0  18.0097
# 1983.0  19.1665
# 1984.0   20.565
# 1985.0  22.2425
# 1986.0  23.3111
# 1987.0  25.1393
# 1988.0  27.0029
# 1989.0  28.3344
# 1990.0  28.7004
# 1991.0  30.1521
# 1992.0  31.7503
# 1993.0  34.1865
# 1994.0  36.2838
# 1995.0  37.3711
# 1996.0  39.3393
# 1997.0  39.5554
# 1998.0  39.6104
# 1999.0  40.9983
# 2000.0  42.4217
# 2001.0   44.809
# 2002.0  48.8091
# 2003.0  56.8341
# 2004.0  66.4879
# 2005.0  75.5005
# 2006.0  82.7374
# 2007.0  89.8911
# 2008.0  93.1188
# 2009.0  96.9986
# 2010.0  103.515
# 2011.0  111.491
# 2012.0  115.689
# 2013.0  119.579
# 2014.0   121.96
# 2015.0  122.753
# 2016.0  123.511
# 2017.0  126.217
# 2018.0  129.966
# 2019.0  135.072
# 2020    115.596
# 2030    139.482
# 2040    163.368
# 2050    187.254
