# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read file
renew = pd.read_csv('clean_data/renewable_energy.csv')
renew
# Out:
#                                country    1965.0    1966.0    1967.0  \
# 0                               Canada  0.000000  0.000000  0.000000
# 1                               Mexico  0.000000  0.000000  0.000000
# 2                                   US  0.133322  0.140620  0.140736
# 3                  Total North America  0.133322  0.140620  0.140736
# 4                            Argentina  0.000000  0.000000  0.000000
# ..                                 ...       ...       ...       ...
# 98                  Total Asia Pacific  0.016440  0.016430  0.014240
# 99                         Total World  0.214179  0.233071  0.235538
# 100                     of which: OECD  0.179852  0.198060  0.199866
# 101                           Non-OECD  0.034327  0.035011  0.035672
# 102                   European Union #  0.029090  0.039790  0.043160
#
#        1968.0    1969.0    1970.0    1971.0    1972.0    1973.0  ...  \
# ...

# %%
renew.at[102, "country"] = "EU"

# %%
renew.at[99, "country"] = "Global"

# %%
renewable_df = renew[renew["country"].isin(["Global", "US", "EU", "India", "China"])]
renewable_df
# Out:
#     country    1965.0    1966.0    1967.0    1968.0    1969.0    1970.0  \
# 2        US  0.133322  0.140620  0.140736  0.155460  0.162271  0.162359
# 82    China  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 84    India  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 99   Global  0.214179  0.233071  0.235538  0.257519  0.269545  0.298667
# 102      EU  0.029090  0.039790  0.043160  0.048180  0.052430  0.069403
#
#        1971.0    1972.0    1973.0  ...    2010.0     2011.0     2012.0  \
# 2    0.165844  0.186730  0.199897  ...  2.756646   3.090966   3.325100
# 82   0.000000  0.000000  0.000000  ...  0.768617   1.049599   1.356394
# 84   0.000000  0.000000  0.000000  ...  0.318274   0.393996   0.460994
# 99   0.322760  0.347499  0.368311  ...  9.699337  11.120646  12.604510
# 102  0.070579  0.069259  0.074422  ...  3.376245   3.980388   4.615612
#
#         2013.0     2014.0     2015.0     2016.0     2017.0     2018.0  \
# ...

# %%
# Flip the df
renewT = renewable_df.T
renewT = renewT.reset_index(drop=False)
# Rename columns
renewT = renewT.rename(columns={"index":"year", 99: "oil"})
# all_energyT.set_index("year", inplace=True)
renewT

renew_final = renewT.rename(columns={2:'US', 82:'China', 84:'India', 'oil' :'Global', 102:'EU'})

renew_final = renew_final.iloc[1:]
renew_final.reset_index(drop=True, inplace=True)
renew_final.head()
# Out:
#      year        US China India    Global       EU
# 0  1965.0  0.133322     0     0  0.214179  0.02909
# 1  1966.0   0.14062     0     0  0.233071  0.03979
# 2  1967.0  0.140736     0     0  0.235538  0.04316
# 3  1968.0   0.15546     0     0  0.257519  0.04818
# 4  1969.0  0.162271     0     0  0.269545  0.05243

# %%
# To see the trend lines

# %%
plt.scatter(renew_final.year, renew_final.US)

# %%
plt.scatter(renew_final.year, renew_final.China)

# %%
plt.scatter(renew_final.year, renew_final.India)

# %%
plt.scatter(renew_final.year, renew_final.Global)

# %%
plt.scatter(renew_final.year, renew_final.EU)

# %%
# Check types
renew_final.dtypes
# Out:
# year      object
# US        object
# China     object
# India     object
# Global    object
# EU        object
# dtype: object

# %%
# Convert types
renew_final = renew_final[["year", "Global", "US", "EU", "India", "China"]].astype(float)
renew_final
# Out:
#       year     Global        US        EU     India     China
# 0   1965.0   0.214179  0.133322  0.029090  0.000000  0.000000
# 1   1966.0   0.233071  0.140620  0.039790  0.000000  0.000000
# 2   1967.0   0.235538  0.140736  0.043160  0.000000  0.000000
# 3   1968.0   0.257519  0.155460  0.048180  0.000000  0.000000
# 4   1969.0   0.269545  0.162271  0.052430  0.000000  0.000000
# 5   1970.0   0.298667  0.162359  0.069403  0.000000  0.000000
# 6   1971.0   0.322760  0.165844  0.070579  0.000000  0.000000
# 7   1972.0   0.347499  0.186730  0.069259  0.000000  0.000000
# 8   1973.0   0.368311  0.199897  0.074422  0.000000  0.000000
# 9   1974.0   0.385606  0.204043  0.078293  0.000000  0.000000
# 10  1975.0   0.388276  0.197543  0.082826  0.000000  0.000000
# 11  1976.0   0.429518  0.225648  0.083056  0.000000  0.000000
# 12  1977.0   0.465105  0.235361  0.086462  0.000000  0.000000
# 13  1978.0   0.507545  0.246788  0.091219  0.000000  0.000000
# ...

# %%
countries_no_zero = renew_final[["year", "Global", "US", "EU"]]
countries_no_zero.head()
# Out:
#      year    Global        US       EU
# 0  1965.0  0.214179  0.133322  0.02909
# 1  1966.0  0.233071  0.140620  0.03979
# 2  1967.0  0.235538  0.140736  0.04316
# 3  1968.0  0.257519  0.155460  0.04818
# 4  1969.0  0.269545  0.162271  0.05243

# %%
# Create columns with nonzero-value
no_zero = renew_final[renew_final["China"] > 3]
no_zero
# Out:
#       year     Global        US        EU     India     China
# 51  2016.0  20.057078  4.807667  6.050515  0.729589  3.439668
# 52  2017.0  23.036529  5.239283  6.692393  0.896848  4.614891
# 53  2018.0  25.825912  5.503936  6.969224  1.103764  5.805106
# 54  2019.0  28.976463  5.828555  7.541291  1.207505  6.627562

# %%
# Create columns with nonzero-value
no_zero_india = renew_final[renew_final["India"] > 0.1]
no_zero_india
# Out:
#       year     Global        US        EU     India     China
# 41  2006.0   5.026240  1.468457  1.835124  0.145510  0.143089
# 42  2007.0   5.944938  1.679495  2.210652  0.184962  0.196720
# 43  2008.0   7.158576  2.107577  2.575745  0.228126  0.326148
# 44  2009.0   8.240148  2.394484  2.917109  0.265121  0.524563
# 45  2010.0   9.699337  2.756646  3.376245  0.318274  0.768617
# 46  2011.0  11.120646  3.090966  3.980388  0.393996  1.049599
# 47  2012.0  12.604510  3.325100  4.615612  0.460994  1.356394
# 48  2013.0  14.360242  3.756286  5.023238  0.518092  1.795909
# 49  2014.0  16.027352  4.039290  5.383986  0.579871  2.238405
# 50  2015.0  18.081068  4.248825  6.023025  0.597314  2.623552
# 51  2016.0  20.057078  4.807667  6.050515  0.729589  3.439668
# 52  2017.0  23.036529  5.239283  6.692393  0.896848  4.614891
# 53  2018.0  25.825912  5.503936  6.969224  1.103764  5.805106
# 54  2019.0  28.976463  5.828555  7.541291  1.207505  6.627562

# %%
two_countries_ori = renew_final[["year", "India", "China"]]
two_countries_ori_sele = two_countries_ori.iloc[:25]
two_countries_ori_sele
# Out:
#       year  India  China
# 0   1965.0    0.0    0.0
# 1   1966.0    0.0    0.0
# 2   1967.0    0.0    0.0
# 3   1968.0    0.0    0.0
# 4   1969.0    0.0    0.0
# 5   1970.0    0.0    0.0
# 6   1971.0    0.0    0.0
# 7   1972.0    0.0    0.0
# 8   1973.0    0.0    0.0
# 9   1974.0    0.0    0.0
# 10  1975.0    0.0    0.0
# 11  1976.0    0.0    0.0
# 12  1977.0    0.0    0.0
# 13  1978.0    0.0    0.0
# 14  1979.0    0.0    0.0
# 15  1980.0    0.0    0.0
# 16  1981.0    0.0    0.0
# 17  1982.0    0.0    0.0
# 18  1983.0    0.0    0.0
# 19  1984.0    0.0    0.0
# 20  1985.0    0.0    0.0
# 21  1986.0    0.0    0.0
# 22  1987.0    0.0    0.0
# 23  1988.0    0.0    0.0
# 24  1989.0    0.0    0.0

# %%
# two_countries = no_zero[["year"]]
# two_countries[["India","China"]] = np.log(no_zero[["India", "China"]])
# two_countries.head()

# %%
two_countries = no_zero[["year", "India", "China"]]
two_countries.head()
# Out:
#       year     India     China
# 51  2016.0  0.729589  3.439668
# 52  2017.0  0.896848  4.614891
# 53  2018.0  1.103764  5.805106
# 54  2019.0  1.207505  6.627562

# %%
two_countries_log = two_countries[["year", "India","China"]]
two_countries_log
# Out:
#       year     India     China
# 51  2016.0  0.729589  3.439668
# 52  2017.0  0.896848  4.614891
# 53  2018.0  1.103764  5.805106
# 54  2019.0  1.207505  6.627562

# %%
# Combine the two above for a new dataframe with log values
two_countries_all = two_countries_ori_sele.append(two_countries_log)
two_countries_all = two_countries_all.reset_index(drop=True)
two_countries_all
# Out:
#       year     India     China
# 0   1965.0  0.000000  0.000000
# 1   1966.0  0.000000  0.000000
# 2   1967.0  0.000000  0.000000
# 3   1968.0  0.000000  0.000000
# 4   1969.0  0.000000  0.000000
# 5   1970.0  0.000000  0.000000
# 6   1971.0  0.000000  0.000000
# 7   1972.0  0.000000  0.000000
# 8   1973.0  0.000000  0.000000
# 9   1974.0  0.000000  0.000000
# 10  1975.0  0.000000  0.000000
# 11  1976.0  0.000000  0.000000
# 12  1977.0  0.000000  0.000000
# 13  1978.0  0.000000  0.000000
# 14  1979.0  0.000000  0.000000
# 15  1980.0  0.000000  0.000000
# 16  1981.0  0.000000  0.000000
# 17  1982.0  0.000000  0.000000
# 18  1983.0  0.000000  0.000000
# 19  1984.0  0.000000  0.000000
# 20  1985.0  0.000000  0.000000
# 21  1986.0  0.000000  0.000000
# 22  1987.0  0.000000  0.000000
# 23  1988.0  0.000000  0.000000
# 24  1989.0  0.000000  0.000000
# 25  2016.0  0.729589  3.439668
# 26  2017.0  0.896848  4.614891
# 27  2018.0  1.103764  5.805106
# 28  2019.0  1.207505  6.627562

# %%
plt.scatter(renew_final.year, renew_final.India)

# %%
plt.scatter(no_zero_india.year, no_zero_india.India)

# %%
plt.scatter(renew_final.year, renew_final.China)

# %%
plt.scatter(no_zero.year, no_zero.China)

# %%
plt.scatter(two_countries_all.year, two_countries_all.China)

# %%
plt.scatter(two_countries_log.year, two_countries_log.China)

# %%
plt.scatter(no_zero.year, no_zero.Global)

# %%
plt.scatter(no_zero.year, no_zero.US)

# %% [markdown]
# ## Will seperate countries in two batch, India & China, the rest together

# %% [markdown]
# #### countries_no_zero

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = countries_no_zero.year.values.reshape(-1, 1)
y = np.log(countries_no_zero[["US", "EU"]])

print(X.shape, y.shape)
# Out:
# (55, 1) (55, 2)

# %%
# Split the data into training and testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# Create a LinearRegression model and fit it to the scaled training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
# Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
# plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2
models = []

from sklearn.metrics import mean_squared_error

lr_predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, lr_predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "LinearRegression",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.0402328284019258, R2: 0.9529305003773582

# %%
#  LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01)
lasso.fit(X_train_scaled, y_train_scaled)

las_predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, las_predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "Lasso",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.039977878701726206, R2: 0.9532307205768757

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01)
elasticnet.fit(X_train_scaled, y_train_scaled)

ela_predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, ela_predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "ElasticNet",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.03998096571961317, R2: 0.9532270653860182

# %%
a = pd.DataFrame(models)
a
# Out:
#               model       MSE        R2
# 0  LinearRegression  0.040233  0.952931
# 1             Lasso  0.039978  0.953231
# 2        ElasticNet  0.039981  0.953227

# %%
a[a["R2"]==a["R2"].max()]
# Out:
#    model       MSE        R2
# 1  Lasso  0.039978  0.953231

# %%
a[a["MSE"]==a["MSE"].min()]
# Out:
#    model       MSE        R2
# 1  Lasso  0.039978  0.953231

# %% [markdown]
# ### Using Lasso

# %%
new_years = [2020, 2030, 2040, 2050]

# %%
year_df = pd.DataFrame(new_years, columns = ['year'])
year_df
# Out:
#    year
# 0  2020
# 1  2030
# 2  2040
# 3  2050

# %%
# Assign X (data) and y (target)
new_X = year_df["year"].values.reshape(-1, 1)

# %%
# Create a StandardScaler model for the new_X

new_X_scaled = X_scaler.transform(new_X)

# %%
# Prediction
energy_predictions = np.exp(lasso.predict(new_X_scaled))

# %%
y_new_inverse = y_scaler.inverse_transform(energy_predictions)
y_new_inverse
# Out:
# array([[ 5.98222835,  8.3790382 ],
#        [11.3123493 , 16.10367211],
#        [21.0831549 , 30.16374243],
#        [38.99431358, 55.75532122]])

# %%
non_zero_countries_prediction = pd.DataFrame(y_new_inverse, columns=["US", "EU"])
non_zero_countries_prediction
# Out:
#           US         EU
# 0   5.982228   8.379038
# 1  11.312349  16.103672
# 2  21.083155  30.163742
# 3  38.994314  55.755321

# %%
non_zero_countries = pd.concat([year_df, non_zero_countries_prediction], axis=1)
non_zero_countries
# Out:
#    year         US         EU
# 0  2020   5.982228   8.379038
# 1  2030  11.312349  16.103672
# 2  2040  21.083155  30.163742
# 3  2050  38.994314  55.755321

# %% [markdown]
# ### no_zero df for India

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = no_zero.year.values.reshape(-1, 1)
y = no_zero[["India"]]
# y = two_countries_log[["India", "China"]]

print(X.shape, y.shape)
# Out:
# (4, 1) (4, 1)

# %%
# Create a LinearRegression model and fit it to the scaled training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# model.fit(renew_X, ln_Y)
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Note: we have to transform our min and max values 
# so they are in the format: array([[ 1.17]])
# This is the required format for `model.predict()`

x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[2016.]]
# Max X Value: [[2019.]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max
# y_min = model.predict(x_min)
# y_max = model.predict(x_max)
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
# Plot X and y using plt.scatter
# Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')

# %%
new_years = [2020, 2030, 2040, 2050]
year_df = pd.DataFrame(new_years, columns = ['year'])
year_df
# Out:
#    year
# 0  2020
# 1  2030
# 2  2040
# 3  2050

# %%
# # Predictions
# predict_2020 = np.exp(model.predict([[2020]]))
# predict_2020 = list(predict_2020[0])
# predict_2020 = predict_2020[0]

# predict_2030 = np.exp(model.predict([[2030]]))
# predict_2030 = list(predict_2030[0])
# predict_2030 = predict_2030[0]

# predict_2040 = np.exp(model.predict([[2040]]))
# predict_2040 = list(predict_2040[0])
# predict_2040 = predict_2040[0]

# predict_2050 = np.exp(model.predict([[2050]]))
# predict_2050 = list(predict_2050[0])
# predict_2050 = predict_2050[0]

# %%
# Predictions
predict_2020 = model.predict([[2020]])
predict_2020 = list(predict_2020[0])
predict_2020 = predict_2020[0]

predict_2030 = model.predict([[2030]])
predict_2030 = list(predict_2030[0])
predict_2030 = predict_2030[0]

predict_2040 = model.predict([[2040]])
predict_2040 = list(predict_2040[0])
predict_2040 = predict_2040[0]

predict_2050 = model.predict([[2050]])
predict_2050 = list(predict_2050[0])
predict_2050 = predict_2050[0]

# %%
predict_values = [predict_2020, predict_2030, predict_2040, predict_2050]
data_years = {"year":new_years,
           "India": predict_values}

# %%
india_predict_df = pd.DataFrame(data_years, columns=["year", 'India'])
india_predict_df
# Out:
#    year     India
# 0  2020  1.394593
# 1  2030  3.035258
# 2  2040  4.675923
# 3  2050  6.316587

# %% [markdown]
# ### no_zero df for China

# %%
# # Assign the data to X and y
# # Note: Sklearn requires a two-dimensional array of values
# # so we use reshape to create this

# X = two_countries_log.year.values.reshape(-1, 1)
# y = two_countries_log[["China"]]

# print(X.shape, y.shape)

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = no_zero.year.values.reshape(-1, 1)
y = no_zero[["China"]]

print(X.shape, y.shape)
# Out:
# (4, 1) (4, 1)

# %%
# Create a LinearRegression model and fit it to the scaled training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# model.fit(renew_X, ln_Y)
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Note: we have to transform our min and max values 
# so they are in the format: array([[ 1.17]])
# This is the required format for `model.predict()`

x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[2016.]]
# Max X Value: [[2019.]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max
# y_min = model.predict(x_min)
# y_max = model.predict(x_max)
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
# Plot X and y using plt.scatter
# Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')

# %%
# # Predictions
# predict_2020 = np.exp(model.predict([[2020]]))
# predict_2020 = list(predict_2020[0])
# predict_2020 = predict_2020[0]

# predict_2030 = np.exp(model.predict([[2030]]))
# predict_2030 = list(predict_2030[0])
# predict_2030 = predict_2030[0]

# predict_2040 = np.exp(model.predict([[2040]]))
# predict_2040 = list(predict_2040[0])
# predict_2040 = predict_2040[0]

# predict_2050 = np.exp(model.predict([[2050]]))
# predict_2050 = list(predict_2050[0])
# predict_2050 = predict_2050[0]

# %%
# Predictions
predict_2020 = model.predict([[2020]])
predict_2020 = list(predict_2020[0])
predict_2020 = predict_2020[0]

predict_2030 = model.predict([[2030]])
predict_2030 = list(predict_2030[0])
predict_2030 = predict_2030[0]

predict_2040 = model.predict([[2040]])
predict_2040 = list(predict_2040[0])
predict_2040 = predict_2040[0]

predict_2050 = model.predict([[2050]])
predict_2050 = list(predict_2050[0])
predict_2050 = predict_2050[0]

# %%
china_predict_values = [predict_2020, predict_2030, predict_2040, predict_2050]
data_years = {"year":new_years,
           "China": china_predict_values}

# %%
china_predict_df = pd.DataFrame(data_years, columns=["year", 'China'])
china_predict_df
# Out:
#    year      China
# 0  2020   7.810281
# 1  2030  18.564179
# 2  2040  29.318077
# 3  2050  40.071974

# %% [markdown]
# ### The predictions look unreasonable for India and China, so will use statsmodel to predict and compare

# %%
import statsmodels.api as sm

# %%
test_X = two_countries_log["year"]
test_X = sm.add_constant(test_X, has_constant='add')

# %%
test_y = two_countries_log[["China"]]

# %%
mod = sm.OLS(test_y, test_X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  China   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     300.9
# Date:                Sun, 28 Mar 2021   Prob (F-statistic):            0.00331
# Time:                        21:53:52   Log-Likelihood:                 3.6144
# No. Observations:                   4   AIC:                            -3.229
# Df Residuals:                       2   BIC:                            -4.456
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2164.4771    125.079    -17.305      0.003   -2702.647   -1626.307
# ...

# %%
xa = np.exp(-594.6947)
xb = np.exp(0.2956)
print("xa", xa)
print("xb", xb)
# Out:
# xa 5.337936128412285e-259
# xb 1.3439324763125928

# %%
def linear_predictions(t):
    return xa * xb ** t

# %%
# prediction_2030
no_zero['china_predict'] = no_zero.year.apply(linear_predictions)
no_zero
# Out:
# /Users/yyh/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       year     Global        US        EU     India     China  china_predict
# 51  2016.0  20.057078  4.807667  6.050515  0.729589  3.439668       3.438035
# 52  2017.0  23.036529  5.239283  6.692393  0.896848  4.614891       4.620486
# 53  2018.0  25.825912  5.503936  6.969224  1.103764  5.805106       6.209622
# 54  2019.0  28.976463  5.828555  7.541291  1.207505  6.627562       8.345312

# %%
plt.plot(no_zero.year, no_zero.China, 'red')
plt.plot(no_zero.year, no_zero.china_predict, 'blue')
plt.title('Predicted Renewable Energy Consumption')
plt.xlabel('Years')
plt.ylabel('Renewable Energy Consumption')
# Out:
# Text(0, 0.5, 'Renewable Energy Consumption')

# %%
years_addon = [2020, 2030, 2040, 2050]
new_data = {"years":years_addon,
           "predictions": years_addon}
years_addon_df = pd.DataFrame(new_data, columns=["years", 'predictions'])
years_addon_df["predictions"] = years_addon_df.apply(linear_predictions)
years_addon_df
# Out:
#    years   predictions
# 0   2020     11.215536
# 1   2030    215.573086
# 2   2040   4143.516076
# 3   2050  79642.249210

# %% [markdown]
# ### It's about the same trend as the machine learning, so I will just go with the machine learning predictions

# %% [markdown]
# ## Add to the previous df

# %%
# Read file
global_renew = pd.read_csv('clean_data/renew_global_predictions.csv')
global_renew
# Out:
#    Unnamed: 0  years  predictions
# 0           0   2020    21.232078
# 1           1   2030    51.101937
# 2           2   2040   122.993520
# 3           3   2050   296.024120

# %%
global_renew_df = global_renew[['years', 'predictions']]
global_renew_df = global_renew_df.rename(columns={"years":"year", "predictions": "Global"})
global_renew_df
# Out:
#    year      Global
# 0  2020   21.232078
# 1  2030   51.101937
# 2  2040  122.993520
# 3  2050  296.024120

# %%
# Add the predictions to each column
global_only = renew_final[['year','Global']]
global_only_all = global_only.append(global_renew_df)
global_only_all.set_index('year', inplace=True)
global_only_all
# Out:
#             Global
# year
# 1965.0    0.214179
# 1966.0    0.233071
# 1967.0    0.235538
# 1968.0    0.257519
# 1969.0    0.269545
# 1970.0    0.298667
# 1971.0    0.322760
# 1972.0    0.347499
# 1973.0    0.368311
# 1974.0    0.385606
# 1975.0    0.388276
# 1976.0    0.429518
# 1977.0    0.465105
# 1978.0    0.507545
# 1979.0    0.557800
# 1980.0    0.604134
# 1981.0    0.632315
# 1982.0    0.743240
# 1983.0    0.843447
# 1984.0    0.956693
# 1985.0    1.010417
# 1986.0    1.147124
# 1987.0    1.213562
# 1988.0    1.257334
# 1989.0    1.404412
# 1990.0    1.579746
# 1991.0    1.656818
# 1992.0    1.745224
# 1993.0    1.815543
# 1994.0    1.913737
# 1995.0    2.007832
# 1996.0    2.040488
# 1997.0    2.195189
# 1998.0    2.314628
# 1999.0    2.460757
# 2000.0    2.639702
# 2001.0    2.754379
# 2002.0    3.097275
# 2003.0    3.370340
# 2004.0    3.869028
# 2005.0    4.371778
# 2006.0    5.026240
# 2007.0    5.944938
# 2008.0    7.158576
# 2009.0    8.240148
# 2010.0    9.699337
# ...

# %%
china_only = renew_final[["year", "China"]]
china_only_all = china_only.append(china_predict_df)
china_only_all.set_index('year', inplace=True)
china_only_all
# Out:
#             China
# year
# 1965.0   0.000000
# 1966.0   0.000000
# 1967.0   0.000000
# 1968.0   0.000000
# 1969.0   0.000000
# 1970.0   0.000000
# 1971.0   0.000000
# 1972.0   0.000000
# 1973.0   0.000000
# 1974.0   0.000000
# 1975.0   0.000000
# 1976.0   0.000000
# 1977.0   0.000000
# 1978.0   0.000000
# 1979.0   0.000000
# 1980.0   0.000000
# 1981.0   0.000000
# 1982.0   0.000000
# 1983.0   0.000000
# 1984.0   0.000000
# 1985.0   0.000000
# 1986.0   0.000000
# 1987.0   0.000000
# 1988.0   0.000000
# 1989.0   0.000000
# 1990.0   0.000680
# 1991.0   0.000751
# 1992.0   0.002473
# 1993.0   0.003331
# 1994.0   0.008488
# 1995.0   0.036372
# 1996.0   0.016359
# 1997.0   0.029310
# 1998.0   0.028496
# 1999.0   0.030107
# 2000.0   0.031489
# 2001.0   0.033018
# 2002.0   0.035471
# 2003.0   0.041101
# 2004.0   0.057830
# 2005.0   0.101235
# 2006.0   0.143089
# 2007.0   0.196720
# 2008.0   0.326148
# 2009.0   0.524563
# 2010.0   0.768617
# 2011.0   1.049599
# 2012.0   1.356394
# ...

# %%
india_only = renew_final[["year", "India"]]
india_only_all = india_only.append(india_predict_df)
india_only_all.set_index('year', inplace=True)
india_only_all
# Out:
#            India
# year
# 1965.0  0.000000
# 1966.0  0.000000
# 1967.0  0.000000
# 1968.0  0.000000
# 1969.0  0.000000
# 1970.0  0.000000
# 1971.0  0.000000
# 1972.0  0.000000
# 1973.0  0.000000
# 1974.0  0.000000
# 1975.0  0.000000
# 1976.0  0.000000
# 1977.0  0.000000
# 1978.0  0.000000
# 1979.0  0.000000
# 1980.0  0.000000
# 1981.0  0.000000
# 1982.0  0.000000
# 1983.0  0.000000
# 1984.0  0.000000
# 1985.0  0.000000
# 1986.0  0.000000
# 1987.0  0.000000
# 1988.0  0.000000
# 1989.0  0.000000
# 1990.0  0.000679
# 1991.0  0.002080
# 1992.0  0.002079
# 1993.0  0.003468
# 1994.0  0.005716
# 1995.0  0.010613
# 1996.0  0.016406
# 1997.0  0.019757
# 1998.0  0.023776
# 1999.0  0.031381
# 2000.0  0.033788
# 2001.0  0.042583
# 2002.0  0.042954
# 2003.0  0.053512
# 2004.0  0.084781
# 2005.0  0.098864
# 2006.0  0.145510
# 2007.0  0.184962
# 2008.0  0.228126
# 2009.0  0.265121
# 2010.0  0.318274
# 2011.0  0.393996
# 2012.0  0.460994
# 2013.0  0.518092
# 2014.0  0.579871
# 2015.0  0.597314
# ...

# %%
nozero_only = renew_final[["year", "US", "EU"]]
nozero_only_all = nozero_only.append(non_zero_countries)
nozero_only_all.set_index('year', inplace=True)
nozero_only_all
# Out:
#                US         EU
# year
# 1965.0   0.133322   0.029090
# 1966.0   0.140620   0.039790
# 1967.0   0.140736   0.043160
# 1968.0   0.155460   0.048180
# 1969.0   0.162271   0.052430
# 1970.0   0.162359   0.069403
# 1971.0   0.165844   0.070579
# 1972.0   0.186730   0.069259
# 1973.0   0.199897   0.074422
# 1974.0   0.204043   0.078293
# 1975.0   0.197543   0.082826
# 1976.0   0.225648   0.083056
# 1977.0   0.235361   0.086462
# 1978.0   0.246788   0.091219
# 1979.0   0.257560   0.092913
# 1980.0   0.266561   0.103978
# 1981.0   0.273776   0.100949
# 1982.0   0.264050   0.093057
# 1983.0   0.298103   0.095990
# 1984.0   0.356072   0.099855
# 1985.0   0.364095   0.104726
# 1986.0   0.387201   0.124135
# 1987.0   0.426796   0.122421
# 1988.0   0.424041   0.131548
# 1989.0   0.512408   0.131837
# 1990.0   0.670078   0.187564
# 1991.0   0.713814   0.195407
# 1992.0   0.765212   0.212959
# 1993.0   0.802285   0.242770
# 1994.0   0.813046   0.263797
# 1995.0   0.787385   0.298167
# ...

# %%
# Combine dataframe
renew_combine1 = pd.concat([global_only_all, nozero_only_all], axis=1)
renew_combine2 = pd.concat([renew_combine1, india_only_all], axis=1)
renew_combine_all = pd.concat([renew_combine2, china_only_all], axis=1)

# %%
renew_combine_all
# Out:
#             Global         US         EU     India      China
# year
# 1965.0    0.214179   0.133322   0.029090  0.000000   0.000000
# 1966.0    0.233071   0.140620   0.039790  0.000000   0.000000
# 1967.0    0.235538   0.140736   0.043160  0.000000   0.000000
# 1968.0    0.257519   0.155460   0.048180  0.000000   0.000000
# 1969.0    0.269545   0.162271   0.052430  0.000000   0.000000
# 1970.0    0.298667   0.162359   0.069403  0.000000   0.000000
# 1971.0    0.322760   0.165844   0.070579  0.000000   0.000000
# 1972.0    0.347499   0.186730   0.069259  0.000000   0.000000
# 1973.0    0.368311   0.199897   0.074422  0.000000   0.000000
# 1974.0    0.385606   0.204043   0.078293  0.000000   0.000000
# 1975.0    0.388276   0.197543   0.082826  0.000000   0.000000
# 1976.0    0.429518   0.225648   0.083056  0.000000   0.000000
# 1977.0    0.465105   0.235361   0.086462  0.000000   0.000000
# 1978.0    0.507545   0.246788   0.091219  0.000000   0.000000
# ...

# %%
# Export dataframe as csv file
renew_combine_all.to_csv("graph_data/renewable_selective_predictions_adjust.csv")
