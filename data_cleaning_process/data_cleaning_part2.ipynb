# %%
# Import dependencies
import pandas as pd
from pyxlsb import open_workbook

from config import postgres_password
from sqlalchemy import create_engine

# %% [markdown]
# # Extract Data Into DataFrames For Nonrenewable Energy Types

# %% [markdown]
# ### Data 1: bp.com Dataset on Oil Consumption (Exajoules)

# %%
# Import data file
oil_file = "raw_data/bp-stats-review-2020-all-data.xlsx"

oil = pd.read_excel(oil_file, "Oil Consumption - EJ", engine="openpyxl")

# Rename the columns with value from the second row
oil_df = oil.rename(columns=oil.iloc[1])
display(oil_df.head(5))
display(oil_df.tail(5))
# Out:
#    Exajoules       1965.0       1966.0       1967.0       1968.0       1969.0  \
# 0        NaN          NaN          NaN          NaN          NaN          NaN
# 1  Exajoules  1965.000000  1966.000000  1967.000000  1968.000000  1969.000000
# 2        NaN          NaN          NaN          NaN          NaN          NaN
# 3     Canada     2.314145     2.438144     2.603182     2.771255     2.885563
# 4     Mexico     0.642414     0.673178     0.720995     0.784022     0.828570
#
#         1970.0       1971.0       1972.0       1973.0  ...       2015.0  \
# 0          NaN          NaN          NaN          NaN  ...          NaN
# 1  1970.000000  1971.000000  1972.000000  1973.000000  ...  2015.000000
# 2          NaN          NaN          NaN          NaN  ...          NaN
# 3     3.077281     3.160261     3.327598     3.511997  ...     4.370752
# 4     0.890909     0.944772     1.063847     1.138484  ...     3.704738
#
# ...

# %% [markdown]
# ### Data 2: bp.com Dataset on Natural Gas Consumption (Exajoules)

# %%
# Import data file
gas_file = "raw_data/bp-stats-review-2020-all-data.xlsx"

gas = pd.read_excel(gas_file, "Gas Consumption - EJ", engine="openpyxl")

# Rename the columns with value from the second row
gas_df = gas.rename(columns=gas.iloc[1])
display(gas_df.head(5))
display(gas_df.tail(5))
# Out:
#    Exajoules       1965.0       1966.0       1967.0       1968.0       1969.0  \
# 0        NaN          NaN          NaN          NaN          NaN          NaN
# 1  Exajoules  1965.000000  1966.000000  1967.000000  1968.000000  1969.000000
# 2        NaN          NaN          NaN          NaN          NaN          NaN
# 3     Canada     0.780063     0.854010     0.906902     1.009875     1.128587
# 4     Mexico     0.290329     0.306408     0.263507     0.282932     0.350894
#
#         1970.0       1971.0       1972.0       1973.0  ...       2015.0  \
# 0          NaN          NaN          NaN          NaN  ...          NaN
# 1  1970.000000  1971.000000  1972.000000  1973.000000  ...  2015.000000
# 2          NaN          NaN          NaN          NaN  ...          NaN
# 3     1.246819     1.330795     1.496861     1.591845  ...     3.951110
# 4     0.358830     0.372940     0.398807     0.441885  ...     2.908185
#
# ...

# %% [markdown]
# ### Data 3: bp.com Dataset on Coal Consumption (Exajoules)

# %%
# Import data file
coal_file = "raw_data/bp-stats-review-2020-all-data.xlsx"

coal = pd.read_excel(coal_file, "Coal Consumption - EJ", engine="openpyxl")

# Rename the columns with value from the second row
coal_df = coal.rename(columns=coal.iloc[1])
display(coal_df.head(5))
display(coal_df.tail(5))
# Out:
#    Exajoules       1965.0       1966.0       1967.0       1968.0       1969.0  \
# 0        NaN          NaN          NaN          NaN          NaN          NaN
# 1  Exajoules  1965.000000  1966.000000  1967.000000  1968.000000  1969.000000
# 2        NaN          NaN          NaN          NaN          NaN          NaN
# 3     Canada     0.647949     0.635221     0.629360     0.683746     0.660133
# 4     Mexico     0.028880     0.030805     0.037798     0.039623     0.040165
#
#         1970.0       1971.0       1972.0       1973.0  ...       2015.0  \
# 0          NaN          NaN          NaN          NaN  ...          NaN
# 1  1970.000000  1971.000000  1972.000000  1973.000000  ...  2015.000000
# 2          NaN          NaN          NaN          NaN  ...          NaN
# 3     0.708742     0.673656     0.635682     0.654690  ...     0.832618
# 4     0.045045     0.056551     0.062502     0.067005  ...     0.531542
#
# ...

# %% [markdown]
# ### Data 4: bp.com Dataset on Nuclear Energy Consumption (Exajoules)

# %%
# Import data file
nuclear_energy_file = "raw_data/bp-stats-review-2020-all-data.xlsx"

nuclear_energy = pd.read_excel(nuclear_energy_file, "Nuclear Consumption - EJ", engine="openpyxl")

# Rename the columns with value from the second row
nuclear_energy_df = nuclear_energy.rename(columns=nuclear_energy.iloc[1])
display(nuclear_energy_df.head(5))
display(nuclear_energy_df.tail(5))
# Out:
#    Exajoules (input-equivalent)      1965.0      1966.0      1967.0  \
# 0                           NaN         NaN         NaN         NaN
# 1  Exajoules (input-equivalent)  1965.00000  1966.00000  1967.00000
# 2                           NaN         NaN         NaN         NaN
# 3                        Canada     0.00128     0.00172     0.00153
# 4                        Mexico     0.00000     0.00000     0.00000
#
#        1968.0      1969.0      1970.0      1971.0      1972.0      1973.0  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1  1968.00000  1969.00000  1970.00000  1971.00000  1972.00000  1973.00000
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3     0.00918     0.00529     0.01037     0.04267     0.07211     0.15254
# 4     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
#
#    ...       2015.0       2016.0       2017.0       2018.0       2019.0  \
# ...

# %% [markdown]
# ### Data 5: bp.com Dataset on Hydroeletric Consumption (Exajoules)

# %%
# Import data file
hydroelec_file = "raw_data/bp-stats-review-2020-all-data.xlsx"

hydroelec = pd.read_excel(hydroelec_file, "Hydro Consumption - EJ", engine="openpyxl")

# Rename the columns with value from the second row
hydroelec_df = hydroelec.rename(columns=hydroelec.iloc[1])
display(hydroelec_df.head(5))
display(hydroelec_df.tail(5))
# Out:
#    Exajoules      1965.0      1966.0      1967.0      1968.0      1969.0  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1  Exajoules  1965.00000  1966.00000  1967.00000  1968.00000  1969.00000
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3     Canada     1.18088     1.31000     1.33924     1.36200     1.50638
# 4     Mexico     0.08863     0.10118     0.11017     0.12642     0.13406
#
#        1970.0      1971.0      1972.0      1973.0  ...       2015.0  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1  1970.00000  1971.00000  1972.00000  1973.00000  ...  2015.000000
# 2         NaN         NaN         NaN         NaN  ...          NaN
# 3     1.58137     1.62461     1.81639     1.94654  ...     3.480689
# 4     0.15005     0.14572     0.15531     0.16371  ...     0.281334
#
#         2016.0       2017.0      2018.0       2019.0                   2019  \
# ...

# %% [markdown]
# # Transform Data for Nonrenewable Energy Type

# %%
# Set up a for loop to iterate through the above df
# df_list = [oil_df, gas_df, coal_df, nuclear_energy_df, hydroelec_df]
for df in oil_df, gas_df, coal_df, nuclear_energy_df, hydroelec_df:
    # Renaming the same name columns (2019) by creating specific name columns and duplicating the according data row
    df ["2019_share"] = df.iloc [:,58]
    df ["2019_growth_rate_per_annum"] = df.iloc [:,56]
    df ["2019_year"] = df.iloc[:,55]

# %%
# Get a list of the column names and select the wanted columns 
# oil_ls = list(oil_df.columns)
# oil_ls

# %%
# gas_ls = list(gas_df.columns)
# gas_ls

# %%
# coal_ls = list(coal_df.columns)
# coal_ls

# %%
nuclear_energy_df_ls = list(nuclear_energy_df.columns)
nuclear_energy_df_ls
# Out:
# ['Exajoules (input-equivalent)',
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  2018.0,
#  2019.0,
#  2019,
#  '2008-18',
#  2019,
#  nan,
#  nan,
#  '2019_share',
#  '2019_growth_rate_per_annum',
#  '2019_year']

# %%
# Rename nuclear energy df's first column
nuclear_energy_df = nuclear_energy_df.rename(columns={nuclear_energy_df.columns[0]: "Exajoules"})

# %%
ls = list(nuclear_energy_df.columns)
ls
# Out:
# ['Exajoules',
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  2018.0,
#  2019.0,
#  2019,
#  '2008-18',
#  2019,
#  nan,
#  nan,
#  '2019_share',
#  '2019_growth_rate_per_annum',
#  '2019_year']

# %%
# hydroelec_df_ls = list(hydroelec_df.columns)
# hydroelec_df_ls

# %%
# Select the wanted columns
columns=['Exajoules',
 1965.0,
 1966.0,
 1967.0,
 1968.0,
 1969.0,
 1970.0,
 1971.0,
 1972.0,
 1973.0,
 1974.0,
 1975.0,
 1976.0,
 1977.0,
 1978.0,
 1979.0,
 1980.0,
 1981.0,
 1982.0,
 1983.0,
 1984.0,
 1985.0,
 1986.0,
 1987.0,
 1988.0,
 1989.0,
 1990.0,
 1991.0,
 1992.0,
 1993.0,
 1994.0,
 1995.0,
 1996.0,
 1997.0,
 1998.0,
 1999.0,
 2000.0,
 2001.0,
 2002.0,
 2003.0,
 2004.0,
 2005.0,
 2006.0,
 2007.0,
 2008.0,
 2009.0,
 2010.0,
 2011.0,
 2012.0,
 2013.0,
 2014.0,
 2015.0,
 2016.0,
 2017.0,
 2018.0,
 '2019_year'
]

# %%
# Select wanted columns
oil_df = oil_df[columns]
gas_df = gas_df[columns]
coal_df = coal_df[columns]
nuclear_energy_df = nuclear_energy_df[columns]
hydroelec_df = hydroelec_df[columns]

# Rename the first and 2019_year column
oil_df = oil_df.rename(columns={oil_df.columns[0]: "country", oil_df.columns[55]: 2019.0})
gas_df = gas_df.rename(columns={gas_df.columns[0]: "country", gas_df.columns[55]: 2019.0})
coal_df = coal_df.rename(columns={coal_df.columns[0]: "country", coal_df.columns[55]: 2019.0})
nuclear_energy_df = nuclear_energy_df.rename(columns={nuclear_energy_df.columns[0]: "country", nuclear_energy_df.columns[55]: 2019.0})
hydroelec_df = hydroelec_df.rename(columns={hydroelec_df.columns[0]: "country", hydroelec_df.columns[55]: 2019.0})

# Dropping nan
oil_df = oil_df.dropna(how="all")
oil_df = oil_df.reset_index(drop=True)

gas_df = gas_df.dropna(how="all")
gas_df = gas_df.reset_index(drop=True)

coal_df = coal_df.dropna(how="all")
coal_df = coal_df.reset_index(drop=True)

nuclear_energy_df = nuclear_energy_df.dropna(how="all")
nuclear_energy_df = nuclear_energy_df.reset_index(drop=True)

hydroelec_df = hydroelec_df.dropna(how="all")
hydroelec_df = hydroelec_df.reset_index(drop=True)

# %%
# Check to see which end rows to remove
display(oil_df.head(2))
display(oil_df.tail(10))
# Out:
#      country       1965.0       1966.0       1967.0       1968.0       1969.0  \
# 0  Exajoules  1965.000000  1966.000000  1967.000000  1968.000000  1969.000000
# 1     Canada     2.314145     2.438144     2.603182     2.771255     2.885563
#
#         1970.0       1971.0       1972.0       1973.0  ...       2010.0  \
# 0  1970.000000  1971.000000  1972.000000  1973.000000  ...  2010.000000
# 1     3.077281     3.160261     3.327598     3.511997  ...     4.431947
#
#        2011.0       2012.0       2013.0       2014.0       2015.0  \
# 0  2011.00000  2012.000000  2013.000000  2014.000000  2015.000000
# 1     4.54219     4.407879     4.410037     4.481114     4.370752
#
#         2016.0       2017.0       2018.0       2019.0
# 0  2016.000000  2017.000000  2018.000000  2019.000000
# 1     4.442217     4.445908     4.589797     4.499921
#
# [2 rows x 56 columns]
#                                                country     1965.0     1966.0  \
# ...

# %%
# Remove unneeded rows
oil_cleaned = oil_df.drop([0, 104, 105, 106, 107, 108, 109, 110, 111])
oil_cleaned = oil_cleaned.reset_index(drop=True)
oil_cleaned.set_index("country", inplace=True)

# %%
# Add suffix to all years
oil_cleaned_suff = oil_cleaned.add_suffix('_oil')
oil_cleaned_suff
# Out:
#                                    1965.0_oil  1966.0_oil  1967.0_oil  \
# country
# Canada                               2.314145    2.438144    2.603182
# Mexico                               0.642414    0.673178    0.720995
# US                                  23.691820   24.875976   25.837584
# Total North America                 26.648378   27.987299   29.161761
# Argentina                            0.936501    0.966833    0.990672
# ...                                       ...         ...         ...
# Total Asia Pacific                   6.828704    7.869195    9.171315
# Total World                         65.191064   70.187240   75.206029
# of which: OECD                      48.712518   52.422477   56.244588
#                  Non-OECD           16.478546   17.764762   18.961442
#                  European Union #   17.027869   18.668342   20.236784
#
#                                    1968.0_oil  1969.0_oil  1970.0_oil  \
# country
# ...

# %%
# Check to see which end rows to remove
display(gas_df.head(2))
display(gas_df.tail(10))
# Out:
#      country       1965.0      1966.0       1967.0       1968.0       1969.0  \
# 0  Exajoules  1965.000000  1966.00000  1967.000000  1968.000000  1969.000000
# 1     Canada     0.780063     0.85401     0.906902     1.009875     1.128587
#
#         1970.0       1971.0       1972.0       1973.0  ...       2010.0  \
# 0  1970.000000  1971.000000  1972.000000  1973.000000  ...  2010.000000
# 1     1.246819     1.330795     1.496861     1.591845  ...     3.178112
#
#         2011.0       2012.0       2013.0       2014.0      2015.0  \
# 0  2011.000000  2012.000000  2013.000000  2014.000000  2015.00000
# 1     3.511123     3.499557     3.753498     3.945339     3.95111
#
#         2016.0       2017.0       2018.0       2019.0
# 0  2016.000000  2017.000000  2018.000000  2019.000000
# 1     3.822709     3.935586     4.258057     4.331249
#
# [2 rows x 56 columns]
#                                                country    1965.0    1966.0  \
# ...

# %%
# Remove unneeded rows
gas_cleaned = gas_df.drop([0, 104, 105, 106, 107, 108, 109, 110, 111, 112])
gas_cleaned = gas_cleaned.reset_index(drop=True)
gas_cleaned.set_index("country", inplace=True)

# %%
# Add suffix to all years
gas_cleaned_suff = gas_cleaned.add_suffix('_gas')
gas_cleaned_suff
# Out:
#                                    1965.0_gas  1966.0_gas  1967.0_gas  \
# country
# Canada                               0.780063    0.854010    0.906902
# Mexico                               0.290329    0.306408    0.263507
# US                                  14.973142   16.137922   17.039478
# Total North America                 16.043534   17.298340   18.209888
# Argentina                            0.148442    0.160766    0.168118
# ...                                       ...         ...         ...
# Total Asia Pacific                   0.202435    0.224601    0.257009
# Total World                         22.693676   24.727660   26.546542
# of which: OECD                      16.978951   18.374413   19.527993
#                  Non-OECD            5.714725    6.353248    7.018548
#                  European Union #    1.352469    1.530108    1.834076
#
#                                    1968.0_gas  1969.0_gas  1970.0_gas  \
# country
# ...

# %%
# Check to see which end rows to remove
display(coal_df.head(2))
display(coal_df.tail(10))
# Out:
#      country       1965.0       1966.0      1967.0       1968.0       1969.0  \
# 0  Exajoules  1965.000000  1966.000000  1967.00000  1968.000000  1969.000000
# 1     Canada     0.647949     0.635221     0.62936     0.683746     0.660133
#
#         1970.0       1971.0       1972.0      1973.0  ...       2010.0  \
# 0  1970.000000  1971.000000  1972.000000  1973.00000  ...  2010.000000
# 1     0.708742     0.673656     0.635682     0.65469  ...     1.036885
#
#         2011.0       2012.0       2013.0       2014.0       2015.0  \
# 0  2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 1     0.928738     0.882526     0.869501     0.821823     0.832618
#
#         2016.0       2017.0       2018.0       2019.0
# 0  2016.000000  2017.000000  2018.000000  2019.000000
# 1     0.782145     0.779341     0.650574     0.558633
#
# [2 rows x 56 columns]
#                                                country     1965.0     1966.0  \
# ...

# %%
# Remove unneeded rows
coal_cleaned = coal_df.drop([0, 104, 105, 106, 107, 108, 109, 110, 111, 112])
coal_cleaned = coal_cleaned.reset_index(drop=True)
coal_cleaned.set_index("country", inplace=True)

# %%
# Add suffix to all years
coal_cleaned_suff = coal_cleaned.add_suffix('_coal')
coal_cleaned_suff
# Out:
#                                    1965.0_coal  1966.0_coal  1967.0_coal  \
# country
# Canada                                0.647949     0.635221     0.629360
# Mexico                                0.028880     0.030805     0.037798
# US                                   11.607279    12.171046    11.941188
# Total North America                  12.284108    12.837073    12.608346
# Argentina                             0.030438     0.025099     0.028225
# ...                                        ...          ...          ...
# Total Asia Pacific                   10.010633    10.553444    10.275475
# Total World                          58.104642    58.766738    57.818915
# of which: OECD                       36.504352    36.342287    35.652930
#                  Non-OECD            21.600290    22.424451    22.165985
#                  European Union #    21.322806    20.436574    19.825952
#
#                                    1968.0_coal  1969.0_coal  1970.0_coal  \
# ...

# %%
# Check to see which end rows to remove
display(nuclear_energy_df.head(2))
display(nuclear_energy_df.tail(10))
# Out:
#                         country      1965.0      1966.0      1967.0  \
# 0  Exajoules (input-equivalent)  1965.00000  1966.00000  1967.00000
# 1                        Canada     0.00128     0.00172     0.00153
#
#        1968.0      1969.0      1970.0      1971.0      1972.0      1973.0  \
# 0  1968.00000  1969.00000  1970.00000  1971.00000  1972.00000  1973.00000
# 1     0.00918     0.00529     0.01037     0.04267     0.07211     0.15254
#
#    ...       2010.0       2011.0       2012.0       2013.0       2014.0  \
# 0  ...  2010.000000  2011.000000  2012.000000  2013.000000  2014.000000
# 1  ...     0.845048     0.867045     0.873514     0.946761     0.976035
#
#        2015.0       2016.0       2017.0       2018.0       2019.0
# 0  2015.00000  2016.000000  2017.000000  2018.000000  2019.000000
# 1     0.92074     0.911875     0.905353     0.895016     0.895769
#
# [2 rows x 56 columns]
#                                                country    1965.0    1966.0  \
# ...

# %%
# Remove unneeded rows
nuclear_energy_cleaned = nuclear_energy_df.drop([0, 104, 105, 106, 107, 108, 109, 110, 111])
nuclear_energy_cleaned = nuclear_energy_cleaned.reset_index(drop=True)
nuclear_energy_cleaned.set_index("country", inplace=True)

# %%
# Add suffix to all years
nuclear_energy_cleaned_suff = nuclear_energy_cleaned.add_suffix('_nuclear')
nuclear_energy_cleaned_suff
# Out:
#                                    1965.0_nuclear  1966.0_nuclear  \
# country
# Canada                                   0.001280        0.001720
# Mexico                                   0.000000        0.000000
# US                                       0.038492        0.058104
# Total North America                      0.039772        0.059824
# Argentina                                0.000000        0.000000
# ...                                           ...             ...
# Total Asia Pacific                       0.000250        0.005840
# Total World                              0.255397        0.344333
# of which: OECD                           0.236792        0.323574
#                  Non-OECD                0.018606        0.020759
#                  European Union #        0.196770        0.257910
#
#                                    1967.0_nuclear  1968.0_nuclear  \
# country
# Canada                                   0.001530        0.009180
# ...

# %%
# Check to see which end rows to remove
display(hydroelec_df.head(2))
display(hydroelec_df.tail(10))
# Out:
#      country      1965.0   1966.0      1967.0    1968.0      1969.0  \
# 0  Exajoules  1965.00000  1966.00  1967.00000  1968.000  1969.00000
# 1     Canada     1.18088     1.31     1.33924     1.362     1.50638
#
#        1970.0      1971.0      1972.0      1973.0  ...       2010.0  \
# 0  1970.00000  1971.00000  1972.00000  1973.00000  ...  2010.000000
# 1     1.58137     1.62461     1.81639     1.94654  ...     3.298275
#
#         2011.0       2012.0       2013.0       2014.0       2015.0  \
# 0  2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 1     3.505227     3.526113     3.611066     3.504354     3.480689
#
#         2016.0       2017.0     2018.0       2019.0
# 0  2016.000000  2017.000000  2018.0000  2019.000000
# 1     3.489418     3.551286     3.4526     3.405087
#
# [2 rows x 56 columns]
#                                                country    1965.0    1966.0  \
# 102                                           Non-OECD  2.090479  2.289389
# ...

# %%
# Remove unneeded rows
hydroelec_cleaned = hydroelec_df.drop([0, 104, 105, 106, 107, 108, 109, 110, 111])
hydroelec_cleaned = hydroelec_cleaned.reset_index(drop=True)
hydroelec_cleaned.set_index("country", inplace=True)

# %%
# Add suffix to all years
hydroelec_cleaned_suff = hydroelec_cleaned.add_suffix('_hydroelec')
hydroelec_cleaned_suff
# Out:
#                                    1965.0_hydroelec  1966.0_hydroelec  \
# country
# Canada                                     1.180880          1.310000
# Mexico                                     0.088630          0.101180
# US                                         1.989741          1.999369
# Total North America                        3.259251          3.410549
# Argentina                                  0.012250          0.012410
# ...                                             ...               ...
# Total Asia Pacific                         1.560896          1.623118
# Total World                                9.231979          9.838170
# of which: OECD                             7.141501          7.548781
#                  Non-OECD                  2.090479          2.289389
#                  European Union #          2.164180          2.349898
#
#                                    1967.0_hydroelec  1968.0_hydroelec  \
# country
# ...

# %% [markdown]
# ### Combine DFs

# %%
# oil_cleaned gas_cleaned coal_cleaned nuclear_energy_cleaned hydroelec_cleaned
data_combine1 = pd.concat([oil_cleaned_suff, gas_cleaned_suff], axis=1)
data_combine2 = pd.concat([data_combine1, coal_cleaned_suff], axis=1)
data_combine3 = pd.concat([data_combine2, nuclear_energy_cleaned_suff], axis=1)
data_combine_all = pd.concat([data_combine3, hydroelec_cleaned_suff], axis=1) 
data_combine_all
# Out:
#                                    1965.0_oil  1966.0_oil  1967.0_oil  \
# country
# Canada                               2.314145    2.438144    2.603182
# Mexico                               0.642414    0.673178    0.720995
# US                                  23.691820   24.875976   25.837584
# Total North America                 26.648378   27.987299   29.161761
# Argentina                            0.936501    0.966833    0.990672
# ...                                       ...         ...         ...
# Total Asia Pacific                   6.828704    7.869195    9.171315
# Total World                         65.191064   70.187240   75.206029
# of which: OECD                      48.712518   52.422477   56.244588
#                  Non-OECD           16.478546   17.764762   18.961442
#                  European Union #   17.027869   18.668342   20.236784
#
#                                    1968.0_oil  1969.0_oil  1970.0_oil  \
# country
# ...

# %% [markdown]
# ## Import the Cleaned Nonrenewable and Emission Data

# %%
# data_combine_all.filter(regex='^1965.0',axis=1)

# %%
# # Import data file
# nonrenewable_file = "clean_data/nonrenewable_energy.csv"

# nonrenewable_df = pd.read_csv(nonrenewable_file)
# nonrenewable_df

# %%
# Import data file
emission_file = "clean_data/emissions.csv"

emission_df = pd.read_csv(emission_file)
emission_df
# Out:
#                                country  1965.0_co2_emission  \
# 0                               Canada           260.332557
# 1                               Mexico            62.134189
# 2                                   US          3480.084706
# 3                  Total North America          3802.551452
# 4                            Argentina            77.341494
# ..                                 ...                  ...
# 98                  Total Asia Pacific          1425.188935
# 99                         Total World         11207.741166
# 100                     of which: OECD          7703.189788
# 101                           Non-OECD          3504.551378
# 102                   European Union #          3304.482212
#
#      1966.0_co2_emission  1967.0_co2_emission  1968.0_co2_emission  \
# 0             271.698929           285.537480           308.284201
# 1              65.056561            66.648353            72.171786
# ...

# %%
# Import data file
renewable_file = "clean_data/renewable_energy.csv"

renewable_df = pd.read_csv(renewable_file)
renewable_df
# Out:
#                                country    1965.0    1966.0    1967.0  \
# 0                               Canada  0.000000  0.000000  0.000000
# 1                               Mexico  0.000000  0.000000  0.000000
# 2                                   US  0.133322  0.140620  0.140736
# 3                  Total North America  0.133322  0.140620  0.140736
# 4                            Argentina  0.000000  0.000000  0.000000
# ..                                 ...       ...       ...       ...
# 98                  Total Asia Pacific  0.016440  0.016430  0.014240
# 99                         Total World  0.214179  0.233071  0.235538
# 100                     of which: OECD  0.179852  0.198060  0.199866
# 101                           Non-OECD  0.034327  0.035011  0.035672
# 102                   European Union #  0.029090  0.039790  0.043160
#
#        1968.0    1969.0    1970.0    1971.0    1972.0    1973.0  ...  \
# ...

# %%
# Import data file
renewable_per_file = "clean_data/renewable_percent.csv"

renewable_per_df = pd.read_csv(renewable_per_file)
renewable_per_df
# Out:
#                                country  1965.0_renewable_per  \
# 0                               Canada              0.000000
# 1                               Mexico              0.000000
# 2                                   US              0.254268
# 3                  Total North America              0.228259
# 4                            Argentina              0.000000
# ..                                 ...                   ...
# 98                  Total Asia Pacific              0.088295
# 99                         Total World              0.137567
# 100                     of which: OECD              0.163869
# 101                           Non-OECD              0.074726
# 102                   European Union #              0.069109
#
#      1966.0_renewable_per  1967.0_renewable_per  1968.0_renewable_per  \
# 0                0.000000              0.000000              0.000000
# 1                0.000000              0.000000              0.000000
# ...

# %% [markdown]
# ## More Combination and Transformation

# %% [markdown]
# ### Combine Nonrenewable Energy Types with Renewable Energy and Emissions

# %%
# Reset index
emission_df.set_index("country", inplace=True)

# %%
# Concat
energy_emissions = pd.concat([data_combine_all, emission_df], axis=1)
energy_emissions
# Out:
#                                    1965.0_oil  1966.0_oil  1967.0_oil  \
# Canada                               2.314145    2.438144    2.603182
# Mexico                               0.642414    0.673178    0.720995
# US                                  23.691820   24.875976   25.837584
# Total North America                 26.648378   27.987299   29.161761
# Argentina                            0.936501    0.966833    0.990672
# ...                                       ...         ...         ...
# Total Asia Pacific                   6.828704    7.869195    9.171315
# Total World                         65.191064   70.187240   75.206029
# of which: OECD                      48.712518   52.422477   56.244588
#                  Non-OECD           16.478546   17.764762   18.961442
#                  European Union #   17.027869   18.668342   20.236784
#
#                                    1968.0_oil  1969.0_oil  1970.0_oil  \
# ...

# %%
# Reset index
renewable_df.set_index("country", inplace=True)

# %%
# Add suffix
renewable_df = renewable_df.add_suffix('_renewable')

# %%
# Concat
all_energy_emissions = pd.concat([renewable_df, energy_emissions], axis=1)
all_energy_emissions
# Out:
#                                    1965.0_renewable  1966.0_renewable  \
# Canada                                     0.000000          0.000000
# Mexico                                     0.000000          0.000000
# US                                         0.133322          0.140620
# Total North America                        0.133322          0.140620
# Argentina                                  0.000000          0.000000
# ...                                             ...               ...
# Total Asia Pacific                         0.016440          0.016430
# Total World                                0.214179          0.233071
# of which: OECD                             0.179852          0.198060
#                  Non-OECD                  0.034327          0.035011
#                  European Union #          0.029090          0.039790
#
#                                    1967.0_renewable  1968.0_renewable  \
# ...

# %% [markdown]
# ### Nonrenewable Energy Types in Percentage (Energy Type/Nonrenewable)

# %%
# # Reset index
# nonrenewable_df.set_index("country", inplace=True)

# %%
# Get the percentage 
# nonrenewable_df oil_cleaned gas_cleaned coal_cleaned nuclear_energy_cleaned hydroelec_cleaned
# oil_cleaned_div = oil_cleaned.divide(nonrenewable_df) * 100
# gas_cleaned_div = gas_cleaned.divide(nonrenewable_df) * 100
# coal_cleaned_div = coal_cleaned.divide(nonrenewable_df) * 100
# nuclear_energy_cleaned_div = nuclear_energy_cleaned.divide(nonrenewable_df) * 100
# hydroelec_cleaned = hydroelec_cleaned.divide(nonrenewable_df) * 100

# %%
# Get the sum of the nonrenewable energy
energy_type_sum = oil_cleaned + gas_cleaned + coal_cleaned + nuclear_energy_cleaned + hydroelec_cleaned
oil_percent = (oil_cleaned/energy_type_sum) * 100
gas_percent = (gas_cleaned/energy_type_sum) * 100
coal_percent = (coal_cleaned /energy_type_sum) * 100
nuclear_percent = (nuclear_energy_cleaned/energy_type_sum) * 100
hydroelec_percent = (hydroelec_cleaned/energy_type_sum) * 100

# %%
# Add suffix
oil_percent_suff = oil_percent.add_suffix('_oil')
gas_percent_suff = gas_percent.add_suffix('_gas')
coal_percent_suff = coal_percent.add_suffix('_coal')
nuclear_percent_suff = nuclear_percent.add_suffix('_nuclear')
hydroelec_percent_suff = hydroelec_percent.add_suffix('_hydroelec')

# %%
# Combine these dataframes
percent_combine1 = pd.concat([oil_percent_suff, gas_percent_suff], axis=1)
percent_combine2 = pd.concat([percent_combine1, coal_percent_suff], axis=1)
percent_combine3 = pd.concat([percent_combine2, nuclear_percent_suff], axis=1)
percent_combine_all = pd.concat([percent_combine3, hydroelec_percent_suff], axis=1) 
percent_combine_all
# Out:
#                                    1965.0_oil  1966.0_oil  1967.0_oil  \
# country
# Canada                              46.994226   46.537504   47.501471
# Mexico                              61.167557   60.560947   63.665675
# US                                  45.299437   45.030571   45.193483
# Total North America                 45.728629   45.439027   45.719753
# Argentina                           83.050271   82.982307   82.574890
# ...                                       ...         ...         ...
# Total Asia Pacific                  36.707704   38.810013   43.181976
# Total World                         41.929781   42.832580   44.228701
# of which: OECD                      44.456228   45.580192   47.043811
#                  Non-OECD           35.898903   36.364000   37.561480
#                  European Union #   40.480769   43.170952   45.510356
#
#                                    1968.0_oil  1969.0_oil  1970.0_oil  \
# country
# ...

# %% [markdown]
# ### Combine Nonrenewable Energy Types with Renewable Energy and Emissions by Percentage

# %%
# Reset index
renewable_per_df.set_index("country", inplace=True)

# %%
# Combine these dataframes
all_per_combine1 = pd.concat([percent_combine_all, renewable_per_df], axis=1)
all_per_combine = pd.concat([all_per_combine1, energy_emissions], axis=1)
all_per_combine
# Out:
#                                    1965.0_oil  1966.0_oil  1967.0_oil  \
# country
# Canada                              46.994226   46.537504   47.501471
# Mexico                              61.167557   60.560947   63.665675
# US                                  45.299437   45.030571   45.193483
# Total North America                 45.728629   45.439027   45.719753
# Argentina                           83.050271   82.982307   82.574890
# ...                                       ...         ...         ...
# Total Asia Pacific                  36.707704   38.810013   43.181976
# Total World                         41.929781   42.832580   44.228701
# of which: OECD                      44.456228   45.580192   47.043811
#                  Non-OECD           35.898903   36.364000   37.561480
#                  European Union #   40.480769   43.170952   45.510356
#
#                                    1968.0_oil  1969.0_oil  1970.0_oil  \
# country
# ...

# %% [markdown]
# # Export Cleaned DataFrames as CSV files

# %%
# Export dataframe as csv file
data_combine_all.to_csv("clean_data/nonrenew_energy_types.csv")
all_energy_emissions.to_csv("clean_data/renewable_nonrenewable_breakdown_emissions.csv")
percent_combine_all.to_csv("clean_data/nonrenew_energy_types_percent.csv")
all_per_combine.to_csv("clean_data/renewable_nonrenewable_breakdown_per_emissions.csv")
