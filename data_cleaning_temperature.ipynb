# %%
# Import dependencies
import pandas as pd
# from pyxlsb import open_workbook

# from config import postgres_password
# from sqlalchemy import create_engine

# %% [markdown]
# # Extract Data Into DataFrames For Temperature

# %% [markdown]
# ### NASA Climate Dataset

# %%
# Import data file
nasa_file = "raw_data/nasa_land_ocean_temp.csv"

nasa_temp = pd.read_csv(nasa_file)
display(nasa_temp.head(5))
display(nasa_temp.tail(5))
# Out:
#    Year  No_Smoothing  Lowess(5)
# 0  1880         -0.16      -0.08
# 1  1881         -0.07      -0.12
# 2  1882         -0.10      -0.16
# 3  1883         -0.16      -0.19
# 4  1884         -0.27      -0.23
#      Year  No_Smoothing  Lowess(5)
# 136  2016          1.02       0.88
# 137  2017          0.93       0.91
# 138  2018          0.85       0.95
# 139  2019          0.98       0.98
# 140  2020          1.02       1.01

# %% [markdown]
# ### Kaggle Temperature Change Dataset

# %%
# Import data file
all_temp_file = "raw_data/Environment_Temperature_change_E_All_Data_NOFLAG.csv"

all_temp = pd.read_csv(all_temp_file, encoding="ISO-8859-1")
display(all_temp.head(5))
display(all_temp.tail(5))
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   °C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   °C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# 1  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2  1.494 -3.187  2.699  2.251 -0.323  2.705  0.086
# 3  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4  2.246 -0.076 -0.497  2.296  0.834  4.418  0.234
#
# [5 rows x 66 columns]
#       Area Code  Area  Months Code               Months  Element Code  \
# 9651       5873  OECD         7018          JunJulAug          6078
# 9652       5873  OECD         7019          SepOctNov          7271
# 9653       5873  OECD         7019          SepOctNov          6078
# 9654       5873  OECD         7020  Meteorological year          7271
# 9655       5873  OECD         7020  Meteorological year          6078
#
#                  Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 9651  Standard Deviation   °C  0.247  0.247  0.247  ...  0.247  0.247  0.247
# 9652  Temperature change   °C  0.036  0.461  0.665  ...  0.958  1.106  0.885
# 9653  Standard Deviation   °C  0.378  0.378  0.378  ...  0.378  0.378  0.378
# 9654  Temperature change   °C  0.165 -0.009  0.134  ...  1.246  0.805  1.274
# 9655  Standard Deviation   °C  0.260  0.260  0.260  ...  0.260  0.260  0.260
#
#       Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 9651  0.247  0.247  0.247  0.247  0.247  0.247  0.247
# 9652  1.041  0.999  1.670  1.535  1.194  0.581  1.233
# 9653  0.378  0.378  0.378  0.378  0.378  0.378  0.378
# 9654  0.991  0.811  1.282  1.850  1.349  1.088  1.297
# 9655  0.260  0.260  0.260  0.260  0.260  0.260  0.260
#
# [5 rows x 66 columns]

# %% [markdown]
# # Transform Data for Energy and Emission

# %% [markdown]
# ### NASA Climate Dataset

# %%
# Extract the wanted columns
list(nasa_temp.columns)
# Out:
# ['Year', 'No_Smoothing', 'Lowess(5)']

# %%
# Lowess smooths the data, no_smoothing 
nasa_temp_df = nasa_temp[["Year", "No_Smoothing", "Lowess(5)"]]
nasa_temp_df.head()
# Out:
#    Year  No_Smoothing  Lowess(5)
# 0  1880         -0.16      -0.08
# 1  1881         -0.07      -0.12
# 2  1882         -0.10      -0.16
# 3  1883         -0.16      -0.19
# 4  1884         -0.27      -0.23

# %%
# Extract year from 1965 to the most recent
nasa_temp_new_df = nasa_temp_df[nasa_temp_df["Year"]>1964]
nasa_temp_new_df.head()
# Out:
#     Year  No_Smoothing  Lowess(5)
# 85  1965         -0.11      -0.05
# 86  1966         -0.06      -0.06
# 87  1967         -0.02      -0.05
# 88  1968         -0.08      -0.03
# 89  1969          0.05      -0.02

# %%
nasa_temp_new_df.reset_index(drop=True).head()
# Out:
#    Year  No_Smoothing  Lowess(5)
# 0  1965         -0.11      -0.05
# 1  1966         -0.06      -0.06
# 2  1967         -0.02      -0.05
# 3  1968         -0.08      -0.03
# 4  1969          0.05      -0.02

# %% [markdown]
# ### Kaggle Temperature Change Dataset

# %%
# Import kaggle data
kaggle_temp = "raw_data/Environment_Temperature_change_E_All_Data_NOFLAG.csv"
kaggle_temp = pd.read_csv(kaggle_temp, encoding="ISO-8859-1")
kaggle_temp.head(50)
# Out:
#     Area Code         Area  Months Code               Months  Element Code  \
# 0           2  Afghanistan         7001              January          7271
# 1           2  Afghanistan         7001              January          6078
# 2           2  Afghanistan         7002             February          7271
# 3           2  Afghanistan         7002             February          6078
# 4           2  Afghanistan         7003                March          7271
# 5           2  Afghanistan         7003                March          6078
# 6           2  Afghanistan         7004                April          7271
# 7           2  Afghanistan         7004                April          6078
# 8           2  Afghanistan         7005                  May          7271
# 9           2  Afghanistan         7005                  May          6078
# 10          2  Afghanistan         7006                 June          7271
# 11          2  Afghanistan         7006                 June          6078
# 12          2  Afghanistan         7007                 July          7271
# 13          2  Afghanistan         7007                 July          6078
# 14          2  Afghanistan         7008               August          7271
# 15          2  Afghanistan         7008               August          6078
# 16          2  Afghanistan         7009            September          7271
# 17          2  Afghanistan         7009            September          6078
# 18          2  Afghanistan         7010              October          7271
# 19          2  Afghanistan         7010              October          6078
# 20          2  Afghanistan         7011             November          7271
# 21          2  Afghanistan         7011             November          6078
# 22          2  Afghanistan         7012             December          7271
# 23          2  Afghanistan         7012             December          6078
# 24          2  Afghanistan         7016          DecJanFeb          7271
# 25          2  Afghanistan         7016          DecJanFeb          6078
# 26          2  Afghanistan         7017          MarAprMay          7271
# 27          2  Afghanistan         7017          MarAprMay          6078
# 28          2  Afghanistan         7018          JunJulAug          7271
# 29          2  Afghanistan         7018          JunJulAug          6078
# 30          2  Afghanistan         7019          SepOctNov          7271
# 31          2  Afghanistan         7019          SepOctNov          6078
# 32          2  Afghanistan         7020  Meteorological year          7271
# 33          2  Afghanistan         7020  Meteorological year          6078
# 34          3      Albania         7001              January          7271
# 35          3      Albania         7001              January          6078
# 36          3      Albania         7002             February          7271
# 37          3      Albania         7002             February          6078
# 38          3      Albania         7003                March          7271
# 39          3      Albania         7003                March          6078
# 40          3      Albania         7004                April          7271
# 41          3      Albania         7004                April          6078
# 42          3      Albania         7005                  May          7271
# 43          3      Albania         7005                  May          6078
# 44          3      Albania         7006                 June          7271
# 45          3      Albania         7006                 June          6078
# 46          3      Albania         7007                 July          7271
# 47          3      Albania         7007                 July          6078
# 48          3      Albania         7008               August          7271
# 49          3      Albania         7008               August          6078
#
#                Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0   Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1   Standard Deviation   °C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2   Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3   Standard Deviation   °C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4   Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
# 5   Standard Deviation   °C  1.512  1.512  1.512  ...  1.512  1.512  1.512
# 6   Temperature change   °C -1.709  0.117  0.919  ...  2.591  1.712  1.417
# 7   Standard Deviation   °C  1.406  1.406  1.406  ...  1.406  1.406  1.406
# 8   Temperature change   °C  1.412 -0.092 -0.690  ...  1.419  3.643  0.909
# 9   Standard Deviation   °C  1.230  1.230  1.230  ...  1.230  1.230  1.230
# 10  Temperature change   °C -0.058 -1.061  1.164  ...  0.594  2.450  0.305
# 11  Standard Deviation   °C  0.930  0.930  0.930  ...  0.930  0.930  0.930
# 12  Temperature change   °C  0.884  0.292  0.348  ...  0.494  0.532  0.973
# 13  Standard Deviation   °C  0.585  0.585  0.585  ...  0.585  0.585  0.585
# 14  Temperature change   °C  0.391 -0.220  0.094  ...  0.587  1.930  1.356
# 15  Standard Deviation   °C  0.773  0.773  0.773  ...  0.773  0.773  0.773
# 16  Temperature change   °C  1.445 -1.797  0.163  ...  0.030  1.408  0.495
# 17  Standard Deviation   °C  0.832  0.832  0.832  ...  0.832  0.832  0.832
# 18  Temperature change   °C -1.102 -0.968  1.654  ...  2.927  1.339  0.827
# 19  Standard Deviation   °C  1.310  1.310  1.310  ...  1.310  1.310  1.310
# 20  Temperature change   °C -0.540 -2.171  0.584  ...  0.975  1.000  1.042
# 21  Standard Deviation   °C  1.391  1.391  1.391  ...  1.391  1.391  1.391
# 22  Temperature change   °C  0.600 -0.721 -0.603  ... -0.154 -1.789 -0.467
# 23  Standard Deviation   °C  1.516  1.516  1.516  ...  1.516  1.516  1.516
# 24  Temperature change   °C -0.731  1.042  1.981  ...  1.921  0.449 -1.858
# 25  Standard Deviation   °C  1.335  1.335  1.335  ...  1.335  1.335  1.335
# 26  Temperature change   °C  0.073  0.454  0.211  ...  2.467  2.034  0.600
# 27  Standard Deviation   °C  0.932  0.932  0.932  ...  0.932  0.932  0.932
# 28  Temperature change   °C  0.406 -0.330  0.535  ...  0.558  1.637  0.878
# 29  Standard Deviation   °C  0.562  0.562  0.562  ...  0.562  0.562  0.562
# 30  Temperature change   °C -0.066 -1.645  0.800  ...  1.311  1.249  0.788
# 31  Standard Deviation   °C  0.783  0.783  0.783  ...  0.783  0.783  0.783
# 32  Temperature change   °C -0.080 -0.120  0.882  ...  1.564  1.342  0.102
# 33  Standard Deviation   °C  0.548  0.548  0.548  ...  0.548  0.548  0.548
# 34  Temperature change   °C  0.180  1.414 -1.783  ...  1.137  0.812 -1.004
# 35  Standard Deviation   °C  1.472  1.472  1.472  ...  1.472  1.472  1.472
# 36  Temperature change   °C -0.625 -2.125 -0.621  ...  0.879  0.554 -2.714
# 37  Standard Deviation   °C  1.939  1.939  1.939  ...  1.939  1.939  1.939
# 38  Temperature change   °C  0.995 -0.782 -1.487  ...  1.079  1.521  2.081
# 39  Standard Deviation   °C  1.356  1.356  1.356  ...  1.356  1.356  1.356
# 40  Temperature change   °C  2.412  0.518  0.601  ...  1.804  1.350  1.320
# 41  Standard Deviation   °C  1.181  1.181  1.181  ...  1.181  1.181  1.181
# 42  Temperature change   °C -0.515  0.568 -0.074  ...  0.938  0.687  0.916
# 43  Standard Deviation   °C  1.173  1.173  1.173  ...  1.173  1.173  1.173
# 44  Temperature change   °C  0.176 -0.772  0.449  ...  0.847  1.384  3.084
# 45  Standard Deviation   °C  0.870  0.870  0.870  ...  0.870  0.870  0.870
# 46  Temperature change   °C -0.338  0.355  1.178  ...  1.676  1.228  3.824
# 47  Standard Deviation   °C  0.715  0.715  0.715  ...  0.715  0.715  0.715
# 48  Temperature change   °C -0.163  2.025  1.229  ...  2.518  2.444  3.130
# 49  Standard Deviation   °C  1.288  1.288  1.288  ...  1.288  1.288  1.288
#
#     Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0   1.233  1.755  1.943  3.416  1.201  1.996  2.951
# 1   1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2   1.494 -3.187  2.699  2.251 -0.323  2.705  0.086
# 3   2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4   2.246 -0.076 -0.497  2.296  0.834  4.418  0.234
# 5   1.512  1.512  1.512  1.512  1.512  1.512  1.512
# 6  -0.052  0.585  1.589  0.980  1.252  1.442  0.899
#
y1969  Y1970  ...  Y2010  Y2011  Y2012  Y2013  Y2014  Y2015  Y2016  Y2017  \
# 0 -2.298  0.804  ...  3.601  1.179 -0.583  1.233  1.755  1.943  3.416  1.201
# 1  1.950  1.950  ...  1.950  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2 -3.167  1.809  ...  1.212  0.321 -3.201  1.494 -3.187  2.699  2.251 -0.323
# 3  2.597  2.597  ...  2.597  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4  2.481 -0.915  ...  3.390  0.748 -0.527  2.246 -0.076 -0.497  2.296  0.834
#
#    Y2018  Y2019
# 0  1.996  2.951
# 1  1.950  1.950
# 2  2.705  0.086
# 3  2.597  2.597
# 4  4.418  0.234
#
# [5 rows x 59 columns]

# %%
# Extract only temperature change data
new_kaggle = cleaned_temp[cleaned_temp["Element"]=="Temperature change"]
new_kaggle.head(60)
# Out:
#                Area               Months             Element Unit  Y1965  \
# 0       Afghanistan              January  Temperature change   °C  1.868
# 2       Afghanistan             February  Temperature change   °C -0.096
# 4       Afghanistan                March  Temperature change   °C -0.909
# 6       Afghanistan                April  Temperature change   °C -1.816
# 8       Afghanistan                  May  Temperature change   °C -0.190
# 10      Afghanistan                 June  Temperature change   °C -0.422
# 12      Afghanistan                 July  Temperature change   °C  0.116
# 14      Afghanistan               August  Temperature change   °C -0.686
# 16      Afghanistan            September  Temperature change   °C -0.661
# 18      Afghanistan              October  Temperature change   °C  2.211
# 20      Afghanistan             November  Temperature change   °C  1.820
# 22      Afghanistan             December  Temperature change   °C -1.115
# 24      Afghanistan          DecJanFeb  Temperature change   °C -0.621
# 26      Afghanistan          MarAprMay  Temperature change   °C -0.972
# 28      Afghanistan          JunJulAug  Temperature change   °C -0.331
# 30      Afghanistan          SepOctNov  Temperature change   °C  1.123
# 32      Afghanistan  Meteorological year  Temperature change   °C -0.200
# 34          Albania              January  Temperature change   °C  0.635
# 36          Albania             February  Temperature change   °C -4.319
# 38          Albania                March  Temperature change   °C  0.093
# 40          Albania                April  Temperature change   °C -1.076
# 42          Albania                  May  Temperature change   °C -0.781
# 44          Albania                 June  Temperature change   °C  0.174
# 46          Albania                 July  Temperature change   °C  0.899
# 48          Albania               August  Temperature change   °C -1.335
# 50          Albania            September  Temperature change   °C  0.457
# 52          Albania              October  Temperature change   °C -0.395
# 54          Albania             November  Temperature change   °C  0.490
# 56          Albania             December  Temperature change   °C  0.972
# 58          Albania          DecJanFeb  Temperature change   °C -1.078
# 60          Albania          MarAprMay  Temperature change   °C -0.588
# 62          Albania          JunJulAug  Temperature change   °C -0.087
# 64          Albania          SepOctNov  Temperature change   °C  0.184
# 66          Albania  Meteorological year  Temperature change   °C -0.392
# 68          Algeria              January  Temperature change   °C  0.010
# 70          Algeria             February  Temperature change   °C -0.713
# 72          Algeria                March  Temperature change   °C  0.729
# 74          Algeria                April  Temperature change   °C -1.376
# 76          Algeria                  May  Temperature change   °C  0.337
# 78          Algeria                 June  Temperature change   °C -0.808
# 80          Algeria                 July  Temperature change   °C  0.652
# 82          Algeria               August  Temperature change   °C -0.837
# 84          Algeria            September  Temperature change   °C -0.845
# 86          Algeria              October  Temperature change   °C  1.313
# 88          Algeria             November  Temperature change   °C  0.618
# 90          Algeria             December  Temperature change   °C  0.537
# 92          Algeria          DecJanFeb  Temperature change   °C -0.470
# 94          Algeria          MarAprMay  Temperature change   °C -0.103
# 96          Algeria          JunJulAug  Temperature change   °C -0.331
# 98          Algeria          SepOctNov  Temperature change   °C  0.362
# 100         Algeria  Meteorological year  Temperature change   °C -0.135
# 102  American Samoa              January  Temperature change   °C -0.836
# 104  American Samoa             February  Temperature change   °C -0.859
# 106  American Samoa                March  Temperature change   °C -0.625
# 108  American Samoa                April  Temperature change   °C -0.471
# 110  American Samoa                  May  Temperature change   °C -0.232
# 112  American Samoa                 June  Temperature change   °C -0.708
# 114  American Samoa                 July  Temperature change   °C -0.230
# 116  American Samoa               August  Temperature change   °C -0.476
# 118  American Samoa            September  Temperature change   °C -0.298
#
#      Y1966  Y1967  Y1968  Y1969  Y1970  ...  Y2010  Y2011  Y2012  Y2013  \
# 0    3.629 -1.432  0.389 -2.298  0.804  ...  3.601  1.179 -0.583  1.233
# 2    3.397  0.296 -2.055 -3.167  1.809  ...  1.212  0.321 -3.201  1.494
# 4   -0.069 -0.759  0.496  2.481 -0.915  ...  3.390  0.748 -0.527  2.246
# 6   -1.192 -1.496 -0.590 -0.770  1.439  ...  2.591  1.712  1.417 -0.052
# 8   -0.192 -1.307 -1.841 -0.977  1.864  ...  1.419  3.643  0.909  1.201
# 10   1.274 -0.722  0.292 -0.270  0.544  ...  0.594  2.450  0.305  1.924
# 12  -0.267  0.332 -0.256 -0.024 -0.534  ...  0.494  0.532  0.973  1.126
# 14   0.049  0.055 -0.155 -0.442  1.867  ...  0.587  1.930  1.356  0.886
# 16  -0.403  0.583 -0.269 -0.847  0.005  ...  0.030  1.408  0.495  2.586
# 18  -0.428 -0.800 -0.611  1.103  0.542  ...  2.927  1.339  0.827  1.691
# 20  -2.574  1.245  0.471 -0.742  0.881  ...  0.975  1.000  1.042  0.975
# 22  -0.327 -0.347  0.056  1.985 -0.186  ... -0.154 -1.789 -0.467 -0.216
# 24   1.970 -0.488 -0.671 -1.803  1.533  ...  1.921  0.449 -1.858  0.753
# 26  -0.484 -1.187 -0.645  0.245  0.796  ...  2.467  2.034  0.600  1.132
# 28   0.352 -0.112 -0.040 -0.245  0.626  ...  0.558  1.637  0.878  1.312
# 30  -1.135  0.343 -0.136 -0.162  0.476  ...  1.311  1.249  0.788  1.751
# 32   0.176 -0.361 -0.373 -0.491  0.858  ...  1.564  1.342  0.102  1.237
# 34  -1.501 -1.887 -2.290 -0.868  1.797  ...  1.137  0.812 -1.004  1.760
# 36   2.845 -1.224  1.316  0.453  0.136  ...  0.879  0.554 -2.714  1.219
# 38  -0.636  0.477 -0.347 -0.139 -0.031  ...  1.079  1.521  2.081  1.420
# 40   1.285 -0.665  2.185 -0.649  0.307  ...  1.804  1.350  1.320  2.509
# 42  -0.368  0.345  2.723  2.359 -1.951  ...  0.938  0.687  0.916  2.107
# 44   0.128 -1.463 -0.263 -1.001  0.128  ...  0.847  1.384  3.084  0.896
# 46  -0.083  0.129 -0.099 -1.418 -0.467  ...  1.676  1.228  3.824  1.452
# 48   0.830  0.975 -1.870 -0.562  0.184  ...  2.518  2.444  3.130  2.822
# 50   0.291  0.518 -0.427  0.654  0.217  ...  0.296  3.838  2.487  0.880
# 104  1.466  1.526  2.606  0.806  0.956  1.506
# 106    NaN    NaN    NaN    NaN    NaN    NaN
# 108    NaN    NaN    NaN    NaN    NaN    NaN
# 110  0.997  0.697  1.147  1.297  1.097  1.047
# 112  0.756  0.566  1.176  0.976  1.476  1.476
# 114  0.420  0.580  1.010  1.160  0.960  1.360
# 116  0.849  0.279  1.579  1.329  0.879  1.879
# 118  1.718  0.748  1.408  1.758  1.308  1.658
#
# [60 rows x 59 columns]

# %%
new_kaggle.reset_index(drop=True).head()
# Out:
#           Area    Months             Element Unit  Y1965  Y1966  Y1967  Y1968  \
# 0  Afghanistan   January  Temperature change   °C  1.868  3.629 -1.432  0.389
# 1  Afghanistan  February  Temperature change   °C -0.096  3.397  0.296 -2.055
# 2  Afghanistan     March  Temperature change   °C -0.909 -0.069 -0.759  0.496
# 3  Afghanistan     April  Temperature change   °C -1.816 -1.192 -1.496 -0.590
# 4  Afghanistan       May  Temperature change   °C -0.190 -0.192 -1.307 -1.841
#
#    Y1969  Y1970  ...  Y2010  Y2011  Y2012  Y2013  Y2014  Y2015  Y2016  Y2017  \
# 0 -2.298  0.804  ...  3.601  1.179 -0.583  1.233  1.755  1.943  3.416  1.201
# 1 -3.167  1.809  ...  1.212  0.321 -3.201  1.494 -3.187  2.699  2.251 -0.323
# 2  2.481 -0.915  ...  3.390  0.748 -0.527  2.246 -0.076 -0.497  2.296  0.834
# 3 -0.770  1.439  ...  2.591  1.712  1.417 -0.052  0.585  1.589  0.980  1.252
# 4 -0.977  1.864  ...  1.419  3.643  0.909  1.201  0.959  1.862  3.246  3.280
#
#    Y2018  Y2019
# 0  1.996  2.951
# 1  2.705  0.086
# 2  4.418  0.234
# 3  1.442  0.899
# 4  0.855  0.647
#
# [5 rows x 59 columns]

# %%
# Drop quarters and Meteorological year
# A typical meteorological year (TMY) is a set of meteorological data with data values for every hour 
# in a year for a given geographical location. The data are selected from hourly data in a longer time period 
# (normally 10 years or more). For each month in the year the data have been selected from the year that was considered most 
# "typical" for that month. For instance, January might be from 2007, February from 2012 and so on.
delete_me = new_kaggle[new_kaggle['Months'] == "MarAprMay"].index
new_kaggle.drop(delete_me , inplace=True)
delete_me1 = new_kaggle[new_kaggle['Months'] == "JunJulAug"].index
new_kaggle.drop(delete_me1 , inplace=True)
delete_me2 = new_kaggle[new_kaggle['Months'] == "SepOctNov"].index
new_kaggle.drop(delete_me2 , inplace=True)
delete_me2 = new_kaggle[new_kaggle['Months'] == "DecJanFeb"].index
new_kaggle.drop(delete_me2 , inplace=True)
delete_me3 = new_kaggle[new_kaggle['Months'] == "Meteorological year"].index
new_kaggle.drop(delete_me3 , inplace=True)
# Out:
# C:\Users\elesh\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# new_kaggle.head(60)

# %%
# Find average change for one country for 1 year
areas = new_kaggle['Area']
# years = new_kaggle['']

for area in areas:
    (area['Y1965']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-f9bbbc869822> in <module>
#       4
#       5 for area in areas:
# ----> 6     (area['Y1965']).mean()
#
# TypeError: string indices must be integers

# %%
areas
# Out:
# 0       Afghanistan
# 2       Afghanistan
# 4       Afghanistan
# 6       Afghanistan
# 8       Afghanistan
#            ...
# 9636           OECD
# 9638           OECD
# 9640           OECD
# 9642           OECD
# 9644           OECD
# Name: Area, Length: 3408, dtype: object

# %%
afg = new_kaggle[new_kaggle['Area']== "Afghanistan"]
afg
# Out:
#            Area     Months             Element Unit  Y1965  Y1966  Y1967  \
# 0   Afghanistan    January  Temperature change   °C  1.868  3.629 -1.432
# 2   Afghanistan   February  Temperature change   °C -0.096  3.397  0.296
# 4   Afghanistan      March  Temperature change   °C -0.909 -0.069 -0.759
# 6   Afghanistan      April  Temperature change   °C -1.816 -1.192 -1.496
# 8   Afghanistan        May  Temperature change   °C -0.190 -0.192 -1.307
# 10  Afghanistan       June  Temperature change   °C -0.422  1.274 -0.722
# 12  Afghanistan       July  Temperature change   °C  0.116 -0.267  0.332
# 14  Afghanistan     August  Temperature change   °C -0.686  0.049  0.055
# 16  Afghanistan  September  Temperature change   °C -0.661 -0.403  0.583
# 18  Afghanistan    October  Temperature change   °C  2.211 -0.428 -0.800
# 20  Afghanistan   November  Temperature change   °C  1.820 -2.574  1.245
# 22  Afghanistan   December  Temperature change   °C -1.115 -0.327 -0.347
#
#     Y1968  Y1969  Y1970  ...  Y2010  Y2011  Y2012  Y2013  Y2014  Y2015  Y2016  \
# 0   0.389 -2.298  0.804  ...  3.601  1.179 -0.583  1.233  1.755  1.943  3.416
# 2  -2.055 -3.167  1.809  ...  1.212  0.321 -3.201  1.494 -3.187  2.699  2.251
# 4   0.496  2.481 -0.915  ...  3.390  0.748 -0.527  2.246 -0.076 -0.497  2.296
# 6  -0.590 -0.770  1.439  ...  2.591  1.712  1.417 -0.052  0.585  1.589  0.980
# 8  -1.841 -0.977  1.864  ...  1.419  3.643  0.909  1.201  0.959  1.862  3.246
# 10  0.292 -0.270  0.544  ...  0.594  2.450  0.305  1.924  1.492  1.289  1.586
# 12 -0.256 -0.024 -0.534  ...  0.494  0.532  0.973  1.126  0.671  1.092  1.079
# 14 -0.155 -0.442  1.867  ...  0.587  1.930  1.356  0.886  0.706  0.589  0.311
# 16 -0.269 -0.847  0.005  ...  0.030  1.408  0.495  2.586  2.268  0.172  3.016
# 18 -0.611  1.103  0.542  ...  2.927  1.339  0.827  1.691  1.134  1.894  0.792
# 20  0.471 -0.742  0.881  ...  0.975  1.000  1.042  0.975 -0.403  0.512 -1.345
# 22  0.056  1.985 -0.186  ... -0.154 -1.789 -0.467 -0.216  0.005  0.048  3.429
#
#     Y2017  Y2018  Y2019
# 0   1.201  1.996  2.951
# 2  -0.323  2.705  0.086
# 4   0.834  4.418  0.234
# 6   1.252  1.442  0.899
# 8   3.280  0.855  0.647
# 10  2.002  1.786 -0.289
# 12  0.901  1.815  1.885
# 14  0.102  0.982  0.773
# 16  0.930  1.063  2.004
# 18  2.092 -0.103  1.264
# 20  2.089  0.882 -1.051
# 22  0.441  1.311  1.426
#
# [12 rows x 59 columns]

# %%
len(afg)
# Out:
# 12

# %%
(afg['Y1965']).mean()
# Out:
# 0.010000000000000009

# %% [markdown]
# ### Export Cleaned Datasets to SQLite

# %%
# Create the connection using the imported create_engine function and then invoking the connect method on it
connection_string = f"postgres:{postgres_password}@localhost:5432/final_project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Check for tables
# engine.table_names()

# %%
# Load dataframes to postgres
emission_goal_combine.to_sql(name='emission_goals', con=engine, if_exists='replace', index=False)

# %%
bp_co2_all_cleaned.to_sql(name='emissions', con=engine, if_exists='replace', index=True)
bp_nonrewablec.to_sql(name='nonrenewable_energy', con=engine, if_exists='replace', index=True)
bp_rc_all_cleaned.to_sql(name='renewable_energy', con=engine, if_exists='replace', index=True)
bp_ec_all_cleaned.to_sql(name='energy_consumption', con=engine, if_exists='replace', index=True)

# %%
data_combine.to_sql(name='bp_all', con=engine, if_exists='replace', index=True)

# %%
new_data_df.to_sql(name='emission_benchmarks', con=engine, if_exists='replace', index=False)

# %%
## Create the connection using the imported create_engine function and then invoking the connect method on it
# engine = create_engine('sqlite:///VAERS.db', echo=False)
# sqlite_connection = engine.connect()

# %%
# ## Set a variable name with the string of a table name
# sqlite_vaers = "2021VAERS"
# merge_all.to_sql(sqlite_vaers, sqlite_connection, if_exists='fail')

# %%
# ## Close the database connection 
# sqlite_connection.close()
