# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
emission_goals = pd.read_csv('../clean_data/emission_goals.csv')
emission_goals
# Out:
#         country     2030  2040 2050  1965.0_all_energy  1966.0_all_energy  \
# 0        Global   50-125  5-25   <0         155.690938         164.097213
# 1            US   30-130  0-32   <0          52.433795          55.383038
# 2            EU    75-80   0-5   <0          42.093184          43.282622
# 3        Brazil     0-20    <0   <0           0.969469           1.057605
# 4         India  115-155     5   <0           2.217659           2.285377
# 5         China  100-110   0-5   <0           5.516043           5.995001
# 6  South Africa   45-377  5-10   <0           1.275199           1.283121
# 7     Indonesia   50-255  5-30   <0           0.303080           0.300495
#
#    1967.0_all_energy  1968.0_all_energy  1969.0_all_energy  1970.0_all_energy  \
# 0         170.274511         180.646875         192.857279         205.007079
# 1          57.311776          60.799094          64.049612          66.215508
# 2          44.509488          47.391263          50.927589          54.195380
# 3           1.095653           1.252840           1.367832           1.585817
# 4           2.355911           2.517670           2.790898           2.729549
# 5           5.391341           5.445350           6.627664           8.486606
# 6           1.336141           1.410133           1.451920           1.517304
# 7           0.296711           0.316207           0.357009           0.382341
#
#    ...  2010.0_co2_emission  2011.0_co2_emission  2012.0_co2_emission  \
# 0  ...         31085.534841         31973.369818         32273.531532
# 1  ...          5485.715925          5336.435925          5089.974540
# 2  ...          3922.934995          3800.361504          3737.698716
# 3  ...           398.324213           423.761618           442.858031
# 4  ...          1660.654080          1735.150560          1848.132873
# 5  ...          8143.438769          8824.313535          9001.257445
# 6  ...           476.665493           467.761278           463.782634
# 7  ...           428.016230           480.059094           513.002788
#
#    2013.0_co2_emission  2014.0_co2_emission  2015.0_co2_emission  \
# 0         32795.554106         32804.718691         32787.197673
# 1          5249.595898          5254.565096          5141.406746
# 2          3653.468215          3445.591925          3486.935193
# 3           482.871255           503.779772           487.040178
# 4          1929.353035          2083.540801          2149.379180
# 5          9244.003274          9239.855878          9185.990809
# 6           464.160481           469.114585           451.706682
# 7           532.869390           486.137994           497.934985
#
#    2016.0_co2_emission  2017.0_co2_emission  2018.0_co2_emission  \
# 0         32936.066036         33279.491334         34007.891035
# 1          5042.431426          4983.869718          5116.785715
# 2          3498.502547          3527.146451          3466.482504
# 3           450.367978           457.229289           442.250684
# 4          2242.892441          2329.816567          2452.501157
# 5          9137.626592          9297.988543          9507.109644
# 6           470.509701           465.805487           470.377753
# 7           501.997264           526.971609           580.719627
#
#    2019.0_co2_emission
# 0         34169.000782
# 1          4964.693088
# 2          3330.444758
# 3           441.299916
# 4          2480.354461
# 5          9825.801775
# 6           478.823071
# 7           632.085380
#
# [8 rows x 224 columns]

# %%
list(emission_goals.columns)
# Out:
# ['country',
#  '2030',
#  '2040',
#  '2050',
#  '1965.0_all_energy',
#  '1966.0_all_energy',
#  '1967.0_all_energy',
#  '1968.0_all_energy',
#  '1969.0_all_energy',
#  '1970.0_all_energy',
#  '1971.0_all_energy',
#  '1972.0_all_energy',
#  '1973.0_all_energy',
#  '1974.0_all_energy',
#  '1975.0_all_energy',
#  '1976.0_all_energy',
#  '1977.0_all_energy',
#  '1978.0_all_energy',
#  '1979.0_all_energy',
#  '1980.0_all_energy',
#  '1981.0_all_energy',
#  '1982.0_all_energy',
#  '1983.0_all_energy',
#  '1984.0_all_energy',
#  '1985.0_all_energy',
#  '1986.0_all_energy',
#  '1987.0_all_energy',
#  '1988.0_all_energy',
#  '1989.0_all_energy',
#  '1990.0_all_energy',
#  '1991.0_all_energy',
#  '1992.0_all_energy',
#  '1993.0_all_energy',
#  '1994.0_all_energy',
#  '1995.0_all_energy',
#  '1996.0_all_energy',
#  '1997.0_all_energy',
#  '1998.0_all_energy',
#  '1999.0_all_energy',
#  '2000.0_all_energy',
#  '2001.0_all_energy',
#  '2002.0_all_energy',
#  '2003.0_all_energy',
#  '2004.0_all_energy',
#  '2005.0_all_energy',
#  '2006.0_all_energy',
#  '2007.0_all_energy',
#  '2008.0_all_energy',
#  '2009.0_all_energy',
#  '2010.0_all_energy',
#  '2011.0_all_energy',
#  '2012.0_all_energy',
#  '2013.0_all_energy',
#  '2014.0_all_energy',
#  '2015.0_all_energy',
#  '2016.0_all_energy',
#  '2017.0_all_energy',
#  '2018.0_all_energy',
#  '2019.0_all_energy',
#  '1965.0_renewable_per',
#  '1966.0_renewable_per',
#  '1967.0_renewable_per',
#  '1968.0_renewable_per',
#  '1969.0_renewable_per',
#  '1970.0_renewable_per',
#  '1971.0_renewable_per',
#  '1972.0_renewable_per',
#  '1973.0_renewable_per',
#  '1974.0_renewable_per',
#  '1975.0_renewable_per',
#  '1976.0_renewable_per',
#  '1977.0_renewable_per',
#  '1978.0_renewable_per',
#  '1979.0_renewable_per',
#  '1980.0_renewable_per',
#  '1981.0_renewable_per',
#  '1982.0_renewable_per',
#  '1983.0_renewable_per',
#  '1984.0_renewable_per',
#  '1985.0_renewable_per',
#  '1986.0_renewable_per',
#  '1987.0_renewable_per',
#  '1988.0_renewable_per',
#  '1989.0_renewable_per',
#  '1990.0_renewable_per',
#  '1991.0_renewable_per',
#  '1992.0_renewable_per',
#  '1993.0_renewable_per',
#  '1994.0_renewable_per',
#  '1995.0_renewable_per',
#  '1996.0_renewable_per',
#  '1997.0_renewable_per',
#  '1998.0_renewable_per',
#  '1999.0_renewable_per',
#  '2000.0_renewable_per',
#  '2001.0_renewable_per',
#  '2002.0_renewable_per',
#  '2003.0_renewable_per',
#  '2004.0_renewable_per',
#  '2005.0_renewable_per',
#  '2006.0_renewable_per',
#  '2007.0_renewable_per',
#  '2008.0_renewable_per',
#  '2009.0_renewable_per',
#  '2010.0_renewable_per',
#  '2011.0_renewable_per',
#  '2012.0_renewable_per',
#  '2013.0_renewable_per',
#  '2014.0_renewable_per',
#  '2015.0_renewable_per',
#  '2016.0_renewable_per',
#  '2017.0_renewable_per',
#  '2018.0_renewable_per',
#  '2019.0_renewable_per',
#  '1965.0_nonrenewable_per',
#  '1966.0_nonrenewable_per',
#  '1967.0_nonrenewable_per',
#  '1968.0_nonrenewable_per',
#  '1969.0_nonrenewable_per',
#  '1970.0_nonrenewable_per',
#  '1971.0_nonrenewable_per',
#  '1972.0_nonrenewable_per',
#  '1973.0_nonrenewable_per',
#  '1974.0_nonrenewable_per',
#  '1975.0_nonrenewable_per',
#  '1976.0_nonrenewable_per',
#  '1977.0_nonrenewable_per',
#  '1978.0_nonrenewable_per',
#  '1979.0_nonrenewable_per',
#  '1980.0_nonrenewable_per',
#  '1981.0_nonrenewable_per',
#  '1982.0_nonrenewable_per',
#  '1983.0_nonrenewable_per',
#  '1984.0_nonrenewable_per',
#  '1985.0_nonrenewable_per',
#  '1986.0_nonrenewable_per',
#  '1987.0_nonrenewable_per',
#  '1988.0_nonrenewable_per',
#  '1989.0_nonrenewable_per',
#  '1990.0_nonrenewable_per',
#  '1991.0_nonrenewable_per',
#  '1992.0_nonrenewable_per',
#  '1993.0_nonrenewable_per',
#  '1994.0_nonrenewable_per',
#  '1995.0_nonrenewable_per',
#  '1996.0_nonrenewable_per',
#  '1997.0_nonrenewable_per',
#  '1998.0_nonrenewable_per',
#  '1999.0_nonrenewable_per',
#  '2000.0_nonrenewable_per',
#  '2001.0_nonrenewable_per',
#  '2002.0_nonrenewable_per',
#  '2003.0_nonrenewable_per',
#  '2004.0_nonrenewable_per',
#  '2005.0_nonrenewable_per',
#  '2006.0_nonrenewable_per',
#  '2007.0_nonrenewable_per',
#  '2008.0_nonrenewable_per',
#  '2009.0_nonrenewable_per',
#  '2010.0_nonrenewable_per',
#  '2011.0_nonrenewable_per',
#  '2012.0_nonrenewable_per',
#  '2013.0_nonrenewable_per',
#  '2014.0_nonrenewable_per',
#  '2015.0_nonrenewable_per',
#  '2016.0_nonrenewable_per',
#  '2017.0_nonrenewable_per',
#  '2018.0_nonrenewable_per',
#  '2019.0_nonrenewable_per',
#  '1965.0_co2_emission',
#  '1966.0_co2_emission',
#  '1967.0_co2_emission',
#  '1968.0_co2_emission',
#  '1969.0_co2_emission',
#  '1970.0_co2_emission',
#  '1971.0_co2_emission',
#  '1972.0_co2_emission',
#  '1973.0_co2_emission',
#  '1974.0_co2_emission',
#  '1975.0_co2_emission',
#  '1976.0_co2_emission',
#  '1977.0_co2_emission',
#  '1978.0_co2_emission',
#  '1979.0_co2_emission',
#  '1980.0_co2_emission',
#  '1981.0_co2_emission',
#  '1982.0_co2_emission',
#  '1983.0_co2_emission',
#  '1984.0_co2_emission',
#  '1985.0_co2_emission',
#  '1986.0_co2_emission',
#  '1987.0_co2_emission',
#  '1988.0_co2_emission',
#  '1989.0_co2_emission',
#  '1990.0_co2_emission',
#  '1991.0_co2_emission',
#  '1992.0_co2_emission',
#  '1993.0_co2_emission',
#  '1994.0_co2_emission',
#  '1995.0_co2_emission',
#  '1996.0_co2_emission',
#  '1997.0_co2_emission',
#  '1998.0_co2_emission',
#  '1999.0_co2_emission',
#  '2000.0_co2_emission',
#  '2001.0_co2_emission',
#  '2002.0_co2_emission',
#  '2003.0_co2_emission',
#  '2004.0_co2_emission',
#  '2005.0_co2_emission',
#  '2006.0_co2_emission',
#  '2007.0_co2_emission',
#  '2008.0_co2_emission',
#  '2009.0_co2_emission',
#  '2010.0_co2_emission',
#  '2011.0_co2_emission',
#  '2012.0_co2_emission',
#  '2013.0_co2_emission',
#  '2014.0_co2_emission',
#  '2015.0_co2_emission',
#  '2016.0_co2_emission',
#  '2017.0_co2_emission',
#  '2018.0_co2_emission',
#  '2019.0_co2_emission']

# %%
selected_df = emission_goals[emission_goals["country"].isin(["Global", "US", "EU", "India", "China"])]

# %%
# Pull out data by suffix
all_energy = selected_df.filter(regex='all_energy$',axis=1).head()
# all_energy.drop_suffix('all_energy')
# Flip the df
all_energyT = all_energy.T
all_energyT = all_energyT.reset_index(drop=False)
# Rename columns
all_energyT = all_energyT.rename(columns={"index":"year", 99: "oil"})
# all_energyT.set_index("year", inplace=True)


allenergy_final = all_energyT.rename(columns={0:'Global', 1:'US', 2:'EU', 4 :'India', 5:'China'})
allenergy_final
# Out:
#                  year      Global         US         EU      India       China
# 0   1965.0_all_energy  155.690938  52.433795  42.093184   2.217659    5.516043
# 1   1966.0_all_energy  164.097213  55.383038  43.282622   2.285377    5.995001
# 2   1967.0_all_energy  170.274511  57.311776  44.509488   2.355911    5.391341
# 3   1968.0_all_energy  180.646875  60.799094  47.391263   2.517670    5.445350
# 4   1969.0_all_energy  192.857279  64.049612  50.927589   2.790898    6.627664
# 5   1970.0_all_energy  205.007079  66.215508  54.195380   2.729549    8.486606
# 6   1971.0_all_energy  213.357154  67.591944  55.464640   2.838043   10.061689
# 7   1972.0_all_energy  224.932635  71.064330  58.120014   2.987987   10.846553
# 8   1973.0_all_energy  237.883880  73.984875  61.375230   3.049283   11.449056
# 9   1974.0_all_energy  239.162833  72.120946  60.366645   3.232547   11.805455
# 10  1975.0_all_energy  240.458127  70.361606  59.569814   3.473187   13.221454
# 11  1976.0_all_energy  253.451176  74.193739  62.977041   3.642691   13.920863
# 12  1977.0_all_energy  262.746766  76.144133  63.904461   3.852343   15.180784
# 13  1978.0_all_energy  271.954056  76.489070  66.216497   3.998774   16.647430
# 14  1979.0_all_energy  281.445174  77.391158  68.712498   4.223200   17.147246
# 15  1980.0_all_energy  279.461959  74.582918  66.870106   4.350661   17.482638
# 16  1981.0_all_energy  278.155156  72.395329  64.936388   4.818776   17.247545
# 17  1982.0_all_energy  276.458050  69.377626  63.485414   4.777145   18.009721
# 18  1983.0_all_energy  280.938689  69.070581  63.755558   5.026523   19.166484
# 19  1984.0_all_energy  294.419488  72.744616  65.421817   5.367804   20.564973
# 20  1985.0_all_energy  302.227751  72.564114  68.685030   5.668948   22.242503
# 21  1986.0_all_energy  308.883170  73.004633  69.803749   6.069131   23.311136
# 5   1970  0_all_energy
# 6   1971  0_all_energy
# 7   1972  0_all_energy
# 8   1973  0_all_energy
# 9   1974  0_all_energy
# 10  1975  0_all_energy
# 11  1976  0_all_energy
# 12  1977  0_all_energy
# 13  1978  0_all_energy
# 14  1979  0_all_energy
# 15  1980  0_all_energy
# 16  1981  0_all_energy
# 17  1982  0_all_energy
# 18  1983  0_all_energy
# 19  1984  0_all_energy
# 20  1985  0_all_energy
# 21  1986  0_all_energy
# 22  1987  0_all_energy
# 23  1988  0_all_energy
# 24  1989  0_all_energy
# 25  1990  0_all_energy
# 26  1991  0_all_energy
# 27  1992  0_all_energy
# 28  1993  0_all_energy
# 29  1994  0_all_energy
# 30  1995  0_all_energy
# 31  1996  0_all_energy
# 32  1997  0_all_energy
# 33  1998  0_all_energy
# 34  1999  0_all_energy
# 35  2000  0_all_energy
# 36  2001  0_all_energy
# 37  2002  0_all_energy
# 38  2003  0_all_energy
# 39  2004  0_all_energy
# 40  2005  0_all_energy
# 41  2006  0_all_energy
# 42  2007  0_all_energy
# 43  2008  0_all_energy
# 44  2009  0_all_energy
# 45  2010  0_all_energy
# 46  2011  0_all_energy
# 47  2012  0_all_energy
# 48  2013  0_all_energy
# 49  2014  0_all_energy
# 50  2015  0_all_energy
# 51  2016  0_all_energy
# 52  2017  0_all_energy
# 53  2018  0_all_energy
# 54  2019  0_all_energy

# %%
split_df1.iloc[:,0]
# Out:
# 0     1965
# 1     1966
# 2     1967
# 3     1968
# 4     1969
# 5     1970
# 6     1971
# 7     1972
# 8     1973
# 9     1974
# 10    1975
# 11    1976
# 12    1977
# 13    1978
# 14    1979
# 15    1980
# 16    1981
# 17    1982
# 18    1983
# 19    1984
# 20    1985
# 21    1986
# 22    1987
# 23    1988
# 24    1989
# 25    1990
# 26    1991
# 27    1992
# 28    1993
# 29    1994
# 30    1995
# 31    1996
# 32    1997
# 33    1998
# 34    1999
# 35    2000
# 36    2001
# 37    2002
# 38    2003
# 39    2004
# 40    2005
# 41    2006
# 42    2007
# 43    2008
# 44    2009
# 45    2010
# 46    2011
# 47    2012
# 48    2013
# 49    2014
# 50    2015
# 51    2016
# 52    2017
# 53    2018
# 54    2019
# Name: 0, dtype: object

# %%
allenergy_final[['year']]=split_df1.iloc[:,0]
allenergy_final
# Out:
#     year      Global         US         EU      India       China
# 0   1965  155.690938  52.433795  42.093184   2.217659    5.516043
# 1   1966  164.097213  55.383038  43.282622   2.285377    5.995001
# 2   1967  170.274511  57.311776  44.509488   2.355911    5.391341
# 3   1968  180.646875  60.799094  47.391263   2.517670    5.445350
# 4   1969  192.857279  64.049612  50.927589   2.790898    6.627664
# 5   1970  205.007079  66.215508  54.195380   2.729549    8.486606
# 6   1971  213.357154  67.591944  55.464640   2.838043   10.061689
# 7   1972  224.932635  71.064330  58.120014   2.987987   10.846553
# 8   1973  237.883880  73.984875  61.375230   3.049283   11.449056
allenergy_final['year'] = allenergy_final['year'].astype(int)
allenergy_final.head()
# Out:
#    year      Global         US         EU     India     China
# 0  1965  155.690938  52.433795  42.093184  2.217659  5.516043
# 1  1966  164.097213  55.383038  43.282622  2.285377  5.995001
# 2  1967  170.274511  57.311776  44.509488  2.355911  5.391341
# 3  1968  180.646875  60.799094  47.391263  2.517670  5.445350
# 4  1969  192.857279  64.049612  50.927589  2.790898  6.627664

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = allenergy_final.year.values.reshape(-1, 1)
y = allenergy_final.EU.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (55, 1) (55, 1)

# %%
# Split the data into training and testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# Create a LinearRegression model and fit it to the scaled training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
# Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
# plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2
models = []

from sklearn.metrics import mean_squared_error

lr_predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, lr_predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "LinearRegression",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.3622796762223902, R2: 0.5782633204199743

# %%
#  LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01)
lasso.fit(X_train_scaled, y_train_scaled)

las_predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, las_predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "Lasso",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.36238312024693536, R2: 0.5781428992583763

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01)
elasticnet.fit(X_train_scaled, y_train_scaled)

ela_predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, ela_predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
models.append({"model": "ElasticNet",
            "MSE": MSE,
            "R2":r2})
# Out:
# MSE: 0.36236057044187875, R2: 0.5781691499164561

# %%
a = pd.DataFrame(models)
a
# Out:
#               model       MSE        R2
# 0  LinearRegression  0.362280  0.578263
# 1             Lasso  0.362383  0.578143
# 2        ElasticNet  0.362361  0.578169

# %%
a[a["R2"]==a["R2"].max()]
# Out:
#               model      MSE        R2
# 0  LinearRegression  0.36228  0.578263

# %%
a[a["MSE"]==a["MSE"].min()]
# Out:
#               model      MSE        R2
# 0  LinearRegression  0.36228  0.578263

# %% [markdown]
# ## Using LinearRegression

# %%
new_years = [2020, 2030, 2040, 2050]

# %%
year_df = pd.DataFrame(new_years, columns = ['years'])
year_df
# Out:
#    years
# 0   2020
# 1   2030
# 2   2040
# 3   2050

# %%
# Assign X (data) and y (target)
new_X = year_df["years"].values.reshape(-1, 1)

# %%
# Create a StandardScaler model for the new_X

new_X_scaled = X_scaler.transform(new_X)

# %%
# Prediction
energy_predictions = model.predict(new_X_scaled)

# %%
energy_predictions
# Out:
# array([[1.34070261],
#        [1.81334928],
#        [2.28599594],
#        [2.75864261]])

# %%
y_new_inverse = y_scaler.inverse_transform(energy_predictions)
y_new_inverse
# Out:
# array([[78.55521769],
#        [82.70852586],
#        [86.86183402],
#        [91.01514219]])

# %%
global_allenergy_prediction = pd.DataFrame(y_new_inverse, columns=["EU"])
global_allenergy_prediction
# Out:
#           EU
# 0  78.555218
# 1  82.708526
# 2  86.861834
# 3  91.015142

# %%
eu_allenergy = pd.concat([year_df, global_allenergy_prediction], axis=1)
eu_allenergy
# Out:
#    years         EU
# 0   2020  78.555218
# 1   2030  82.708526
# 2   2040  86.861834
# 3   2050  91.015142

# %%
eu_allenergy.to_csv('eu_allenergy.csv', encoding='utf-8')
