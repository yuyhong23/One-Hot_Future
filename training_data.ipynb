# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
bp_all = pd.read_csv('clean_data/bp_all.csv')
bp_all
# Out:
#                                country  1965.0_all_energy  1966.0_all_energy  \
# 0                               Canada           4.924317           5.239095
# 1                               Mexico           1.050253           1.111572
# 2                                   US          52.433795          55.383038
# 3                  Total North America          58.408365          61.733704
# 4                            Argentina           1.127632           1.165108
# ..                                 ...                ...                ...
# 98                  Total Asia Pacific          18.619358          20.292629
# 99                         Total World         155.690938         164.097213
# 100                     of which: OECD         109.753966         115.209593
# 101                           Non-OECD          45.936972          48.887620
# 102                   European Union #          42.093184          43.282622
#
# ...

# %%
# Read the csv file into a pandas DataFrame
emissions = pd.read_csv('clean_data/emissions.csv')
emissions
# Out:
#                                country  1965.0_co2_emission  \
# 0                               Canada           260.332557
# 1                               Mexico            62.134189
# 2                                   US          3480.084706
# 3                  Total North America          3802.551452
# 4                            Argentina            77.341494
# ..                                 ...                  ...
# 98                  Total Asia Pacific          1425.188935
# 99                         Total World         11207.741166
# 100                     of which: OECD          7703.189788
# 101                           Non-OECD          3504.551378
# 102                   European Union #          3304.482212
#
#      1966.0_co2_emission  1967.0_co2_emission  1968.0_co2_emission  \
# 0             271.698929           285.537480           308.284201
# 1              65.056561            66.648353            72.171786
# ...

# %%
# Read the csv file into a pandas DataFrame
energy_consumption = pd.read_csv('clean_data/energy_consumption.csv')
energy_consumption
# Out:
#                                country  1965.0_all_energy  1966.0_all_energy  \
# 0                               Canada           4.924317           5.239095
# 1                               Mexico           1.050253           1.111572
# 2                                   US          52.433795          55.383038
# 3                  Total North America          58.408365          61.733704
# 4                            Argentina           1.127632           1.165108
# ..                                 ...                ...                ...
# 98                  Total Asia Pacific          18.619358          20.292629
# 99                         Total World         155.690938         164.097213
# 100                     of which: OECD         109.753966         115.209593
# 101                           Non-OECD          45.936972          48.887620
# 102                   European Union #          42.093184          43.282622
#
# ...

# %%
# Read the csv file into a pandas DataFrame
nonrenewable_energy = pd.read_csv('clean_data/nonrenewable_energy.csv')
nonrenewable_energy
# Out:
#                                country      1965.0      1966.0      1967.0  \
# 0                               Canada    4.924317    5.239095    5.480214
# 1                               Mexico    1.050253    1.111572    1.132470
# 2                                   US   52.300473   55.242418   57.171040
# 3                  Total North America   58.275043   61.593084   63.783724
# 4                            Argentina    1.127632    1.165108    1.199725
# ..                                 ...         ...         ...         ...
# 98                  Total Asia Pacific   18.602918   20.276199   21.238757
# 99                         Total World  155.476758  163.864141  170.038973
# 100                     of which: OECD  109.574113  115.011533  119.557890
# 101                           Non-OECD   45.902645   48.852609   50.481083
# 102                   European Union #   42.064094   43.242832   44.466328
#
# ...

# %%
# Read the csv file into a pandas DataFrame
renewable_energy = pd.read_csv('clean_data/renewable_energy.csv')
renewable_energy
# Out:
#                                country    1965.0    1966.0    1967.0  \
# 0                               Canada  0.000000  0.000000  0.000000
# 1                               Mexico  0.000000  0.000000  0.000000
# 2                                   US  0.133322  0.140620  0.140736
# 3                  Total North America  0.133322  0.140620  0.140736
# 4                            Argentina  0.000000  0.000000  0.000000
# ..                                 ...       ...       ...       ...
# 98                  Total Asia Pacific  0.016440  0.016430  0.014240
# 99                         Total World  0.214179  0.233071  0.235538
# 100                     of which: OECD  0.179852  0.198060  0.199866
# 101                           Non-OECD  0.034327  0.035011  0.035672
# 102                   European Union #  0.029090  0.039790  0.043160
#
#        1968.0    1969.0    1970.0    1971.0    1972.0    1973.0  ...  \
# ...

# %%
emissions = emissions.dropna()

# %%
us_df = emissions.iloc[[2]]
us_df
# Out:
#   country  1965.0_co2_emission  1966.0_co2_emission  1967.0_co2_emission  \
# 2      US          3480.084706          3675.466374          3772.622833
#
#    1968.0_co2_emission  1969.0_co2_emission  1970.0_co2_emission  \
# 2          3994.225972          4170.119294          4298.208775
#
#    1971.0_co2_emission  1972.0_co2_emission  1973.0_co2_emission  ...  \
# 2          4340.724935          4564.699478            4764.4009  ...
#
#    2010.0_co2_emission  2011.0_co2_emission  2012.0_co2_emission  \
# 2          5485.715925          5336.435925           5089.97454
#
#    2013.0_co2_emission  2014.0_co2_emission  2015.0_co2_emission  \
# 2          5249.595898          5254.565096          5141.406746
#
#    2016.0_co2_emission  2017.0_co2_emission  2018.0_co2_emission  \
# 2          5042.431426          4983.869718          5116.785715
#
#    2019.0_co2_emission
# 2          4964.693088
#
# [1 rows x 56 columns]

# %%
us_df_t=us_df.T
us_df_t
# Out:
#                            2
# country                   US
# 1965.0_co2_emission  3480.08
# 1966.0_co2_emission  3675.47
# 1967.0_co2_emission  3772.62
# 1968.0_co2_emission  3994.23
# 1969.0_co2_emission  4170.12
# 1970.0_co2_emission  4298.21
# 1971.0_co2_emission  4340.72
# 1972.0_co2_emission   4564.7
# 1973.0_co2_emission   4764.4
# 1974.0_co2_emission  4596.37
# 1975.0_co2_emission  4466.27
# 1976.0_co2_emission  4741.89
# 1977.0_co2_emission  4900.33
# 1978.0_co2_emission  4863.21
# 1979.0_co2_emission  4958.29
# 1980.0_co2_emission  4785.71
# 1981.0_co2_emission  4638.12
# 1982.0_co2_emission  4397.98
# 1983.0_co2_emission  4372.54
# 1984.0_co2_emission  4574.22
# 1985.0_co2_emission  4585.48
# 1986.0_co2_emission  4597.66
# 1987.0_co2_emission  4748.86
# 1988.0_co2_emission  4968.35
# 1989.0_co2_emission  5056.91
# 1990.0_co2_emission  4969.62
# 1991.0_co2_emission  4922.02
# 1992.0_co2_emission  5004.15
# 1993.0_co2_emission  5116.91
# 1994.0_co2_emission   5195.3
# ...

# %%
us_df_t.reset_index(level=0, inplace=True)
us_df_t
# Out:
#                   index        2
# 0               country       US
# 1   1965.0_co2_emission  3480.08
# 2   1966.0_co2_emission  3675.47
# 3   1967.0_co2_emission  3772.62
# 4   1968.0_co2_emission  3994.23
# 5   1969.0_co2_emission  4170.12
# 6   1970.0_co2_emission  4298.21
# 7   1971.0_co2_emission  4340.72
# 8   1972.0_co2_emission   4564.7
# 9   1973.0_co2_emission   4764.4
# 10  1974.0_co2_emission  4596.37
# 11  1975.0_co2_emission  4466.27
# 12  1976.0_co2_emission  4741.89
# 13  1977.0_co2_emission  4900.33
# 14  1978.0_co2_emission  4863.21
# 15  1979.0_co2_emission  4958.29
# 16  1980.0_co2_emission  4785.71
# 17  1981.0_co2_emission  4638.12
# 18  1982.0_co2_emission  4397.98
# 19  1983.0_co2_emission  4372.54
# 20  1984.0_co2_emission  4574.22
# 21  1985.0_co2_emission  4585.48
# 22  1986.0_co2_emission  4597.66
# 23  1987.0_co2_emission  4748.86
# 24  1988.0_co2_emission  4968.35
# 25  1989.0_co2_emission  5056.91
# 26  1990.0_co2_emission  4969.62
# ...

# %%
us_df_t.rename(columns={'index':'year', 2:'emissions'})
# Out:
#                    year emissions
# 0               country        US
# 1   1965.0_co2_emission   3480.08
# 2   1966.0_co2_emission   3675.47
# 3   1967.0_co2_emission   3772.62
# 4   1968.0_co2_emission   3994.23
# 5   1969.0_co2_emission   4170.12
# 6   1970.0_co2_emission   4298.21
# 7   1971.0_co2_emission   4340.72
# 8   1972.0_co2_emission    4564.7
# 9   1973.0_co2_emission    4764.4
# 10  1974.0_co2_emission   4596.37
# 11  1975.0_co2_emission   4466.27
# 12  1976.0_co2_emission   4741.89
# 13  1977.0_co2_emission   4900.33
# 14  1978.0_co2_emission   4863.21
# 15  1979.0_co2_emission   4958.29
# 16  1980.0_co2_emission   4785.71
# 17  1981.0_co2_emission   4638.12
# 18  1982.0_co2_emission   4397.98
# 19  1983.0_co2_emission   4372.54
# 20  1984.0_co2_emission   4574.22
# 21  1985.0_co2_emission   4585.48
# 22  1986.0_co2_emission   4597.66
# 23  1987.0_co2_emission   4748.86
# 24  1988.0_co2_emission   4968.35
# 25  1989.0_co2_emission   5056.91
# ...

# %%
us_df_t = us_df_t.iloc[1:]
us_df_t
# Out:
#                   index        2
# 1   1965.0_co2_emission  3480.08
# 2   1966.0_co2_emission  3675.47
# 3   1967.0_co2_emission  3772.62
# 4   1968.0_co2_emission  3994.23
# 5   1969.0_co2_emission  4170.12
# 6   1970.0_co2_emission  4298.21
# 7   1971.0_co2_emission  4340.72
# 8   1972.0_co2_emission   4564.7
# 9   1973.0_co2_emission   4764.4
# 10  1974.0_co2_emission  4596.37
# 11  1975.0_co2_emission  4466.27
# 12  1976.0_co2_emission  4741.89
# 13  1977.0_co2_emission  4900.33
# 14  1978.0_co2_emission  4863.21
# 15  1979.0_co2_emission  4958.29
# 16  1980.0_co2_emission  4785.71
# 17  1981.0_co2_emission  4638.12
# 18  1982.0_co2_emission  4397.98
# 19  1983.0_co2_emission  4372.54
# 20  1984.0_co2_emission  4574.22
# 21  1985.0_co2_emission  4585.48
# 22  1986.0_co2_emission  4597.66
# 23  1987.0_co2_emission  4748.86
# 24  1988.0_co2_emission  4968.35
# 25  1989.0_co2_emission  5056.91
# 26  1990.0_co2_emission  4969.62
# 27  1991.0_co2_emission  4922.02
# ...

# %%
us_df_new = us_df_t.rename(columns={'index':'year', 2:'emissions'})
us_df_new
# Out:
#                    year emissions
# 1   1965.0_co2_emission   3480.08
# 2   1966.0_co2_emission   3675.47
# 3   1967.0_co2_emission   3772.62
# 4   1968.0_co2_emission   3994.23
# 5   1969.0_co2_emission   4170.12
# 6   1970.0_co2_emission   4298.21
# 7   1971.0_co2_emission   4340.72
# 8   1972.0_co2_emission    4564.7
# 9   1973.0_co2_emission    4764.4
# 10  1974.0_co2_emission   4596.37
# 11  1975.0_co2_emission   4466.27
# 12  1976.0_co2_emission   4741.89
# 13  1977.0_co2_emission   4900.33
# 14  1978.0_co2_emission   4863.21
# 15  1979.0_co2_emission   4958.29
# 16  1980.0_co2_emission   4785.71
# 17  1981.0_co2_emission   4638.12
# 18  1982.0_co2_emission   4397.98
# 19  1983.0_co2_emission   4372.54
# 20  1984.0_co2_emission   4574.22
# 21  1985.0_co2_emission   4585.48
# 22  1986.0_co2_emission   4597.66
# 23  1987.0_co2_emission   4748.86
# 24  1988.0_co2_emission   4968.35
# 25  1989.0_co2_emission   5056.91
# 26  1990.0_co2_emission   4969.62
# ...

# %%
col = us_df_new['year'] 
col_split =[x.split('.') for x in col]
split_df = pd.DataFrame(col_split)
# us_df_new[['years','extra']] = us_df_new[[x.split('.') for x in (us_df_new['year'])]]
split_df
# Out:
#        0               1
# 0   1965  0_co2_emission
# 1   1966  0_co2_emission
# 2   1967  0_co2_emission
# 3   1968  0_co2_emission
# 4   1969  0_co2_emission
# 5   1970  0_co2_emission
# 6   1971  0_co2_emission
# 7   1972  0_co2_emission
# 8   1973  0_co2_emission
# 9   1974  0_co2_emission
# 10  1975  0_co2_emission
# 11  1976  0_co2_emission
# 12  1977  0_co2_emission
# 13  1978  0_co2_emission
# 14  1979  0_co2_emission
# 15  1980  0_co2_emission
# 16  1981  0_co2_emission
# 17  1982  0_co2_emission
# 18  1983  0_co2_emission
# 19  1984  0_co2_emission
# 20  1985  0_co2_emission
# 21  1986  0_co2_emission
# 22  1987  0_co2_emission
# 23  1988  0_co2_emission
# 24  1989  0_co2_emission
# 25  1990  0_co2_emission
# 26  1991  0_co2_emission
# 27  1992  0_co2_emission
# 28  1993  0_co2_emission
# 29  1994  0_co2_emission
# 30  1995  0_co2_emission
# 31  1996  0_co2_emission
# 32  1997  0_co2_emission
# 33  1998  0_co2_emission
# 34  1999  0_co2_emission
# 35  2000  0_co2_emission
# ...

# %%
split_df.iloc[:,0]
# Out:
# 0     1965
# 1     1966
# 2     1967
# 3     1968
# 4     1969
# 5     1970
# 6     1971
# 7     1972
# 8     1973
# 9     1974
# 10    1975
# 11    1976
# 12    1977
# 13    1978
# 14    1979
# 15    1980
# 16    1981
# 17    1982
# 18    1983
# 19    1984
# 20    1985
# 21    1986
# 22    1987
# 23    1988
# 24    1989
# 25    1990
# 26    1991
# 27    1992
# 28    1993
# 29    1994
# 30    1995
# 31    1996
# 32    1997
# 33    1998
# 34    1999
# 35    2000
# 36    2001
# 37    2002
# 38    2003
# 39    2004
# 40    2005
# 41    2006
# 42    2007
# 43    2008
# 44    2009
# 45    2010
# 46    2011
# 47    2012
# 48    2013
# 49    2014
# 50    2015
# 51    2016
# 52    2017
# 53    2018
# 54    2019
# Name: 0, dtype: object

# %%
split_df.index += 1

# %%
us_df_new[['years']]=split_df.iloc[:,0]
us_df_new
# Out:
#                    year    emissions years
# 1   1965.0_co2_emission  3480.084706  1965
# 2   1966.0_co2_emission  3675.466374  1966
# 3   1967.0_co2_emission  3772.622833  1967
# 4   1968.0_co2_emission  3994.225972  1968
# 5   1969.0_co2_emission  4170.119294  1969
# 6   1970.0_co2_emission  4298.208775  1970
# 7   1971.0_co2_emission  4340.724935  1971
# 8   1972.0_co2_emission  4564.699478  1972
# 9   1973.0_co2_emission  4764.400900  1973
# 10  1974.0_co2_emission  4596.370255  1974
# 11  1975.0_co2_emission  4466.274568  1975
# 12  1976.0_co2_emission  4741.894691  1976
# 13  1977.0_co2_emission  4900.330368  1977
# 14  1978.0_co2_emission  4863.210023  1978
# 15  1979.0_co2_emission  4958.288573  1979
# 16  1980.0_co2_emission  4785.714698  1980
# 17  1981.0_co2_emission  4638.120434  1981
# 18  1982.0_co2_emission  4397.975099  1982
# 19  1983.0_co2_emission  4372.541379  1983
# 20  1984.0_co2_emission  4574.223474  1984
# 21  1985.0_co2_emission  4585.480325  1985
# ...

# %%
us_df_new['years'] = pd.to_numeric(us_df_new['years'])
us_df_new
# Out:
#                    year    emissions  years
# 1   1965.0_co2_emission  3480.084706   1965
# 2   1966.0_co2_emission  3675.466374   1966
# 3   1967.0_co2_emission  3772.622833   1967
# 4   1968.0_co2_emission  3994.225972   1968
# 5   1969.0_co2_emission  4170.119294   1969
# 6   1970.0_co2_emission  4298.208775   1970
# 7   1971.0_co2_emission  4340.724935   1971
# 8   1972.0_co2_emission  4564.699478   1972
# 9   1973.0_co2_emission  4764.400900   1973
# 10  1974.0_co2_emission  4596.370255   1974
# 11  1975.0_co2_emission  4466.274568   1975
# 12  1976.0_co2_emission  4741.894691   1976
# 13  1977.0_co2_emission  4900.330368   1977
# 14  1978.0_co2_emission  4863.210023   1978
# 15  1979.0_co2_emission  4958.288573   1979
# 16  1980.0_co2_emission  4785.714698   1980
# 17  1981.0_co2_emission  4638.120434   1981
# 18  1982.0_co2_emission  4397.975099   1982
# 19  1983.0_co2_emission  4372.541379   1983
# 20  1984.0_co2_emission  4574.223474   1984
# ...

# %%
# us_df_new.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = us_df_new.years.values.reshape(-1, 1)
y = us_df_new.emissions.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
X
# Out:
# Shape:  (55, 1) (55, 1)
# array([[1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018],
#        [2019]], dtype=int64)

# %%
# Plot the data
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X, y)
print(model)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[27.36157673]]
# y-axis intercept:  [-49529.98836056]

# %%
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# Out:
# True output: [3480.08470602]
# Predicted output: [4235.50990889]
# Prediction Error: [755.42520286]

# %%
x_min = X.min()
x_max = X.max()

# %%
y_min_actual = y.min()
y_max_actual = y.max()

# %%
y_min = 101.896225057 + 12.44002424 * x_min
y_max = 101.896225057 + 12.44002424 * x_max
# 𝑦=101.896225057+12.44002424𝑥
print(f"Actual Min Value: {y_min_actual}")
print(f"Calculated Min Value: {round(y_min, 8)}")
print(f"Actual Max Value: {y_max_actual}")
print(f"Calculated Max Value: {y_max}")
# Out:
# Actual Min Value: 3480.084706022452
# Calculated Min Value: 24546.54385666
# Actual Max Value: 5884.15120298174
# Calculated Max Value: 25218.305165617

# %%
y_min_predicted = model.predict([[x_min]])
y_max_predicted = model.predict([[x_max]])
print(f"Actual Min Value: {y_min_actual}")
print(f"Predicted Min Value: {y_min_predicted}")
print(f"Actual Max Value: {y_max_actual}")
print(f"Predicted Max Value: {y_max_predicted}")
# Out:
# Actual Min Value: 3480.084706022452
# Predicted Min Value: [[4235.50990889]]
# Actual Max Value: 5884.15120298174
# Predicted Max Value: [[5713.03505217]]

# %%
plt.scatter(X, y, c='blue')
plt.plot([x_min, x_max], [y_min, y_max], c='red')
